# %% [markdown]
# # Dissecting Spotify Valence
#
# This is the third assignment for the course "Applied Machine Learning".
#
# > Nikolas Moatsos <br />
# >Department of Management Science and Technology <br />
# >Athens University of Economics and Business

# %% [markdown]
# Spotify uses a metric called *valence* to measure the happiness of a track. The metric itself, however, was not developed by Spotify. It was originally developed by Echo Nest, a company that was bought by Spotify in 2014. We don't know exactly how valence is calculated. Some details are given by a blog post, which you can find here:
#
# https://web.archive.org/web/20170422195736/http://blog.echonest.com/post/66097438564/plotting-musics-emotional-valence-1950-2013
#
# The task of this assignment is to untangle the mystery behind valence.

# %% [markdown]
# ## Data Collection

# %% [markdown]
# This notebook demonstrates the acquisition of the necessary data for the assignment. To achieve that we will use the API offered by Spotify, which provides information about the general and audio features of a track. The Web API can be found here: https://developer.spotify.com/documentation/web-api/reference/#/
#
# Specifically the endpoints that will be used are:
# * [Get Several Tracks](https://developer.spotify.com/documentation/web-api/reference/#/operations/get-several-tracks), that provides general features about the track.
# * [Get Tracks' Audio Features](https://developer.spotify.com/documentation/web-api/reference/#/operations/get-several-audio-features), that provides audio features about the track, in a higher level.
# * [Get Track's Audio Analysis](https://developer.spotify.com/documentation/web-api/reference/#/operations/get-audio-analysis), that provides audio features about the track, in a lower level.

# %% [markdown]
# *In order to connect with the API we must create a spotify_config.py file that contains our credentials. The file must have the following structure:*
#   ```
#   config = {
#       'client_id' : 'XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX',
#       'client_secret' :'XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX'
#   }
#   ```
#
# * First, we import all the necessary libraries for the data collection.

# %%
import pandas as pd
import numpy as np

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from spotify_config import config

import random
import os

# %% [markdown]
# * In order to obtain a big sample of songs and their ids on Spotify (necessary to use the API), we will use a dataset from *Kaggle* that contains the top 100 songs of each year from 1921 to 2020. The datatset contains 169,909 songs in total and can be found here: https://www.kaggle.com/ektanegi/spotifydata-19212020.
#
# * The dataset includes some features from the Spotify API, although to ensure that we collect the correct data, for now, we will only obtain the id and the song name.

# %%
songs = pd.read_csv('data/data.csv', usecols=['id', 'name'])
songs
# Out:
#                             id                                           name
# 0       6KbQ3uYMLKb5jDxLF7wYDD                    Singende Bataillone 1. Teil
# 1       6KuQTIu1KoTTkLXKrwlLPV       Fantasiestücke, Op. 111: Più tosto lento
# 2       6L63VW0PibdM1HDSBoqnoM                 Chapter 1.18 - Zamek kaniowski
# 3       6M94FkXd15sOAOQYRnWPN8  Bebamos Juntos - Instrumental (Remasterizado)
# 4       6N6tiFZ9vLTSOIxkj8qKrd    Polonaise-Fantaisie in A-Flat Major, Op. 61
# ...                        ...                                            ...
# 169904  4KppkflX7I3vJQk7urOJaS                  Skechers (feat. Tyga) - Remix
# 169905  1ehhGlTvjtHo2e4xJFB0SZ                 Sweeter (feat. Terrace Martin)
# 169906  52eycxprLhK3lPcRLbQiVk                               How Would I Know
# 169907  3wYOGJYD31sLRmBgCvWxa4                                    I Found You
# 169908  60RFlt48hm0l4Fu0JoccOl                          More Hearts Than Mine
#
# [169909 rows x 2 columns]

# %% [markdown]
# * We check for duplicated ids.

# %%
songs.drop_duplicates(subset='id', inplace=True)
songs.shape
# Out:
# (169909, 2)

# %% [markdown]
# * We check for duplicated song names, because the same song can exist with different id (single and album edition). To ensure that we have only unique songs we drop the duplicated names.

# %%
songs.drop_duplicates(subset='name', inplace=True)
songs.shape
# Out:
# (132940, 2)

# %% [markdown]
# * We initialize the spotipy object with our credentials from the *spotify_config.py* file.

# %%
client_credentials_manager = SpotifyClientCredentials(config['client_id'],
                                                      config['client_secret'])
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %% [markdown]
# * We initialize the list with the ids that will be used to perform the requests.

# %%
all_track_ids = list(songs['id'])

# %% [markdown]
# * Beacause later, when we get the low level analysis features, we will use a subset of the songs (first 60,000), we shuffle the ids to ensure that we will get a random sample.
# * The `random.shuffle` method changes the original list.

# %%
random.seed(0)
random.shuffle(all_track_ids)

# %% [markdown]
# ### Track and High Level Audio Features

# %% [markdown]
# * We get all the high level audio feautures of a track, with the use of the `sp.audio_features` method.
# * Spotify permits a maximum of 100 song ids per batch.
# * We save and return the results in the previously created dictionary.
#
# *The code was obtained from the notes of Professor Louridas.*

# %%
def get_audio_features(track_ids):
    audio_features_dict = {}
    start = 0
    num_tracks = 100

    while start < len(track_ids):
        print(f'getting from {start} to {start+num_tracks}')
        try:
            tracks_batch = track_ids[start:start+num_tracks]
            audio_batch = sp.audio_features(tracks_batch)
            audio_features_dict.update({ track_id : features 
                            for track_id, features in zip(tracks_batch, audio_batch) })
        except Exception:
            print('error:', start)
        start += num_tracks
        
    return audio_features_dict

# %%
audio_features = get_audio_features(all_track_ids)
# Out:
# getting from 0 to 100
# getting from 100 to 200
# getting from 200 to 300
# getting from 300 to 400
# getting from 400 to 500
# getting from 500 to 600
# getting from 600 to 700
# getting from 700 to 800
# getting from 800 to 900
# getting from 900 to 1000
# getting from 1000 to 1100
# getting from 1100 to 1200
# getting from 1200 to 1300
# getting from 1300 to 1400
# getting from 1400 to 1500
# getting from 1500 to 1600
# getting from 1600 to 1700
# getting from 1700 to 1800
# getting from 1800 to 1900
# getting from 1900 to 2000
# getting from 2000 to 2100
# getting from 2100 to 2200
# getting from 2200 to 2300
# getting from 2300 to 2400
# getting from 2400 to 2500
# getting from 2500 to 2600
# getting from 2600 to 2700
# getting from 2700 to 2800
# getting from 2800 to 2900
# getting from 2900 to 3000
# getting from 3000 to 3100
# getting from 3100 to 3200
# getting from 3200 to 3300
# getting from 3300 to 3400
# getting from 3400 to 3500
# getting from 3500 to 3600
# getting from 3600 to 3700
# getting from 3700 to 3800
# getting from 3800 to 3900
# getting from 3900 to 4000
# getting from 4000 to 4100
# getting from 4100 to 4200
# getting from 4200 to 4300
# getting from 4300 to 4400
# getting from 4400 to 4500
# getting from 4500 to 4600
# getting from 4600 to 4700
# getting from 4700 to 4800
# getting from 4800 to 4900
# getting from 4900 to 5000
# getting from 5000 to 5100
# getting from 5100 to 5200
# getting from 5200 to 5300
# getting from 5300 to 5400
# getting from 5400 to 5500
# getting from 5500 to 5600
# getting from 5600 to 5700
# getting from 5700 to 5800
# getting from 5800 to 5900
# getting from 5900 to 6000
# getting from 6000 to 6100
# getting from 6100 to 6200
# getting from 6200 to 6300
# getting from 6300 to 6400
# getting from 6400 to 6500
# getting from 6500 to 6600
# getting from 6600 to 6700
# getting from 6700 to 6800
# getting from 6800 to 6900
# getting from 6900 to 7000
# getting from 7000 to 7100
# getting from 7100 to 7200
# getting from 7200 to 7300
# getting from 7300 to 7400
# getting from 7400 to 7500
# getting from 7500 to 7600
# getting from 7600 to 7700
# getting from 7700 to 7800
# getting from 7800 to 7900
# getting from 7900 to 8000
# getting from 8000 to 8100
# getting from 8100 to 8200
# getting from 8200 to 8300
# getting from 8300 to 8400
# getting from 8400 to 8500
# getting from 8500 to 8600
# getting from 8600 to 8700
# getting from 8700 to 8800
# getting from 8800 to 8900
# getting from 8900 to 9000
# getting from 9000 to 9100
# getting from 9100 to 9200
# getting from 9200 to 9300
# getting from 9300 to 9400
# getting from 9400 to 9500
# getting from 9500 to 9600
# getting from 9600 to 9700
# getting from 9700 to 9800
# getting from 9800 to 9900
# getting from 9900 to 10000
# getting from 10000 to 10100
# getting from 10100 to 10200
# getting from 10200 to 10300
# getting from 10300 to 10400
# getting from 10400 to 10500
# getting from 10500 to 10600
# getting from 10600 to 10700
# getting from 10700 to 10800
# getting from 10800 to 10900
# getting from 10900 to 11000
# getting from 11000 to 11100
# getting from 11100 to 11200
# getting from 11200 to 11300
# getting from 11300 to 11400
# getting from 11400 to 11500
# getting from 11500 to 11600
# getting from 11600 to 11700
# getting from 11700 to 11800
# getting from 11800 to 11900
# getting from 11900 to 12000
# getting from 12000 to 12100
# getting from 12100 to 12200
# getting from 12200 to 12300
# getting from 12300 to 12400
# getting from 12400 to 12500
# getting from 12500 to 12600
# getting from 12600 to 12700
# getting from 12700 to 12800
# getting from 12800 to 12900
# getting from 12900 to 13000
# getting from 13000 to 13100
# getting from 13100 to 13200
# getting from 13200 to 13300
# getting from 13300 to 13400
# getting from 13400 to 13500
# getting from 13500 to 13600
# getting from 13600 to 13700
# getting from 13700 to 13800
# getting from 13800 to 13900
# getting from 13900 to 14000
# getting from 14000 to 14100
# getting from 14100 to 14200
# getting from 14200 to 14300
# getting from 14300 to 14400
# getting from 14400 to 14500
# getting from 14500 to 14600
# getting from 14600 to 14700
# getting from 14700 to 14800
# getting from 14800 to 14900
# getting from 14900 to 15000
# getting from 15000 to 15100
# getting from 15100 to 15200
# getting from 15200 to 15300
# getting from 15300 to 15400
# getting from 15400 to 15500
# getting from 15500 to 15600
# getting from 15600 to 15700
# getting from 15700 to 15800
# getting from 15800 to 15900
# getting from 15900 to 16000
# getting from 16000 to 16100
# getting from 16100 to 16200
# getting from 16200 to 16300
# getting from 16300 to 16400
# getting from 16400 to 16500
# getting from 16500 to 16600
# getting from 16600 to 16700
# getting from 16700 to 16800
# getting from 16800 to 16900
# getting from 16900 to 17000
# getting from 17000 to 17100
# getting from 17100 to 17200
# getting from 17200 to 17300
# getting from 17300 to 17400
# getting from 17400 to 17500
# getting from 17500 to 17600
# getting from 17600 to 17700
# getting from 17700 to 17800
# getting from 17800 to 17900
# getting from 17900 to 18000
# getting from 18000 to 18100
# getting from 18100 to 18200
# getting from 18200 to 18300
# getting from 18300 to 18400
# getting from 18400 to 18500
# getting from 18500 to 18600
# getting from 18600 to 18700
# getting from 18700 to 18800
# getting from 18800 to 18900
# getting from 18900 to 19000
# getting from 19000 to 19100
# getting from 19100 to 19200
# getting from 19200 to 19300
# getting from 19300 to 19400
# getting from 19400 to 19500
# getting from 19500 to 19600
# getting from 19600 to 19700
# getting from 19700 to 19800
# getting from 19800 to 19900
# getting from 19900 to 20000
# getting from 20000 to 20100
# getting from 20100 to 20200
# getting from 20200 to 20300
# getting from 20300 to 20400
# getting from 20400 to 20500
# getting from 20500 to 20600
# getting from 20600 to 20700
# getting from 20700 to 20800
# getting from 20800 to 20900
# getting from 20900 to 21000
# getting from 21000 to 21100
# getting from 21100 to 21200
# getting from 21200 to 21300
# getting from 21300 to 21400
# getting from 21400 to 21500
# getting from 21500 to 21600
# getting from 21600 to 21700
# getting from 21700 to 21800
# getting from 21800 to 21900
# getting from 21900 to 22000
# getting from 22000 to 22100
# getting from 22100 to 22200
# getting from 22200 to 22300
# getting from 22300 to 22400
# getting from 22400 to 22500
# getting from 22500 to 22600
# getting from 22600 to 22700
# getting from 22700 to 22800
# getting from 22800 to 22900
# getting from 22900 to 23000
# getting from 23000 to 23100
# getting from 23100 to 23200
# getting from 23200 to 23300
# getting from 23300 to 23400
# getting from 23400 to 23500
# getting from 23500 to 23600
# getting from 23600 to 23700
# getting from 23700 to 23800
# getting from 23800 to 23900
# getting from 23900 to 24000
# getting from 24000 to 24100
# getting from 24100 to 24200
# getting from 24200 to 24300
# getting from 24300 to 24400
# getting from 24400 to 24500
# getting from 24500 to 24600
# getting from 24600 to 24700
# getting from 24700 to 24800
# getting from 24800 to 24900
# getting from 24900 to 25000
# getting from 25000 to 25100
# getting from 25100 to 25200
# getting from 25200 to 25300
# getting from 25300 to 25400
# getting from 25400 to 25500
# getting from 25500 to 25600
# getting from 25600 to 25700
# getting from 25700 to 25800
# getting from 25800 to 25900
# getting from 25900 to 26000
# getting from 26000 to 26100
# getting from 26100 to 26200
# getting from 26200 to 26300
# getting from 26300 to 26400
# getting from 26400 to 26500
# getting from 26500 to 26600
# getting from 26600 to 26700
# getting from 26700 to 26800
# getting from 26800 to 26900
# getting from 26900 to 27000
# getting from 27000 to 27100
# getting from 27100 to 27200
# getting from 27200 to 27300
# getting from 27300 to 27400
# getting from 27400 to 27500
# getting from 27500 to 27600
# getting from 27600 to 27700
# getting from 27700 to 27800
# getting from 27800 to 27900
# getting from 27900 to 28000
# getting from 28000 to 28100
# getting from 28100 to 28200
# getting from 28200 to 28300
# getting from 28300 to 28400
# getting from 28400 to 28500
# getting from 28500 to 28600
# getting from 28600 to 28700
# getting from 28700 to 28800
# getting from 28800 to 28900
# getting from 28900 to 29000
# getting from 29000 to 29100
# getting from 29100 to 29200
# getting from 29200 to 29300
# getting from 29300 to 29400
# getting from 29400 to 29500
# getting from 29500 to 29600
# getting from 29600 to 29700
# getting from 29700 to 29800
# getting from 29800 to 29900
# getting from 29900 to 30000
# getting from 30000 to 30100
# getting from 30100 to 30200
# getting from 30200 to 30300
# getting from 30300 to 30400
# getting from 30400 to 30500
# getting from 30500 to 30600
# getting from 30600 to 30700
# getting from 30700 to 30800
# getting from 30800 to 30900
# getting from 30900 to 31000
# getting from 31000 to 31100
# getting from 31100 to 31200
# getting from 31200 to 31300
# getting from 31300 to 31400
# getting from 31400 to 31500
# getting from 31500 to 31600
# getting from 31600 to 31700
# getting from 31700 to 31800
# getting from 31800 to 31900
# getting from 31900 to 32000
# getting from 32000 to 32100
# getting from 32100 to 32200
# getting from 32200 to 32300
# getting from 32300 to 32400
# getting from 32400 to 32500
# getting from 32500 to 32600
# getting from 32600 to 32700
# getting from 32700 to 32800
# getting from 32800 to 32900
# getting from 32900 to 33000
# getting from 33000 to 33100
# getting from 33100 to 33200
# getting from 33200 to 33300
# getting from 33300 to 33400
# getting from 33400 to 33500
# getting from 33500 to 33600
# getting from 33600 to 33700
# getting from 33700 to 33800
# getting from 33800 to 33900
# getting from 33900 to 34000
# getting from 34000 to 34100
# getting from 34100 to 34200
# getting from 34200 to 34300
# getting from 34300 to 34400
# getting from 34400 to 34500
# getting from 34500 to 34600
# getting from 34600 to 34700
# getting from 34700 to 34800
# getting from 34800 to 34900
# getting from 34900 to 35000
# getting from 35000 to 35100
# getting from 35100 to 35200
# getting from 35200 to 35300
# getting from 35300 to 35400
# getting from 35400 to 35500
# getting from 35500 to 35600
# getting from 35600 to 35700
# getting from 35700 to 35800
# getting from 35800 to 35900
# getting from 35900 to 36000
# getting from 36000 to 36100
# getting from 36100 to 36200
# getting from 36200 to 36300
# getting from 36300 to 36400
# getting from 36400 to 36500
# getting from 36500 to 36600
# getting from 36600 to 36700
# getting from 36700 to 36800
# getting from 36800 to 36900
# getting from 36900 to 37000
# getting from 37000 to 37100
# getting from 37100 to 37200
# getting from 37200 to 37300
# getting from 37300 to 37400
# getting from 37400 to 37500
# getting from 37500 to 37600
# getting from 37600 to 37700
# getting from 37700 to 37800
# getting from 37800 to 37900
# getting from 37900 to 38000
# getting from 38000 to 38100
# getting from 38100 to 38200
# getting from 38200 to 38300
# getting from 38300 to 38400
# getting from 38400 to 38500
# getting from 38500 to 38600
# getting from 38600 to 38700
# getting from 38700 to 38800
# getting from 38800 to 38900
# getting from 38900 to 39000
# getting from 39000 to 39100
# getting from 39100 to 39200
# getting from 39200 to 39300
# getting from 39300 to 39400
# getting from 39400 to 39500
# getting from 39500 to 39600
# getting from 39600 to 39700
# getting from 39700 to 39800
# getting from 39800 to 39900
# getting from 39900 to 40000
# getting from 40000 to 40100
# getting from 40100 to 40200
# getting from 40200 to 40300
# getting from 40300 to 40400
# getting from 40400 to 40500
# getting from 40500 to 40600
# getting from 40600 to 40700
# getting from 40700 to 40800
# getting from 40800 to 40900
# getting from 40900 to 41000
# getting from 41000 to 41100
# getting from 41100 to 41200
# getting from 41200 to 41300
# getting from 41300 to 41400
# getting from 41400 to 41500
# getting from 41500 to 41600
# getting from 41600 to 41700
# getting from 41700 to 41800
# getting from 41800 to 41900
# getting from 41900 to 42000
# getting from 42000 to 42100
# getting from 42100 to 42200
# getting from 42200 to 42300
# getting from 42300 to 42400
# getting from 42400 to 42500
# getting from 42500 to 42600
# getting from 42600 to 42700
# getting from 42700 to 42800
# getting from 42800 to 42900
# getting from 42900 to 43000
# getting from 43000 to 43100
# getting from 43100 to 43200
# getting from 43200 to 43300
# getting from 43300 to 43400
# getting from 43400 to 43500
# getting from 43500 to 43600
# getting from 43600 to 43700
# getting from 43700 to 43800
# getting from 43800 to 43900
# getting from 43900 to 44000
# getting from 44000 to 44100
# getting from 44100 to 44200
# getting from 44200 to 44300
# getting from 44300 to 44400
# getting from 44400 to 44500
# getting from 44500 to 44600
# getting from 44600 to 44700
# getting from 44700 to 44800
# getting from 44800 to 44900
# getting from 44900 to 45000
# getting from 45000 to 45100
# getting from 45100 to 45200
# getting from 45200 to 45300
# getting from 45300 to 45400
# getting from 45400 to 45500
# getting from 45500 to 45600
# getting from 45600 to 45700
# getting from 45700 to 45800
# getting from 45800 to 45900
# getting from 45900 to 46000
# getting from 46000 to 46100
# getting from 46100 to 46200
# getting from 46200 to 46300
# getting from 46300 to 46400
# getting from 46400 to 46500
# getting from 46500 to 46600
# getting from 46600 to 46700
# getting from 46700 to 46800
# getting from 46800 to 46900
# getting from 46900 to 47000
# getting from 47000 to 47100
# getting from 47100 to 47200
# getting from 47200 to 47300
# getting from 47300 to 47400
# getting from 47400 to 47500
# getting from 47500 to 47600
# getting from 47600 to 47700
# getting from 47700 to 47800
# getting from 47800 to 47900
# getting from 47900 to 48000
# getting from 48000 to 48100
# getting from 48100 to 48200
# getting from 48200 to 48300
# getting from 48300 to 48400
# getting from 48400 to 48500
# getting from 48500 to 48600
# getting from 48600 to 48700
# getting from 48700 to 48800
# getting from 48800 to 48900
# getting from 48900 to 49000
# getting from 49000 to 49100
# getting from 49100 to 49200
# getting from 49200 to 49300
# getting from 49300 to 49400
# getting from 49400 to 49500
# getting from 49500 to 49600
# getting from 49600 to 49700
# getting from 49700 to 49800
# getting from 49800 to 49900
# getting from 49900 to 50000
# getting from 50000 to 50100
# getting from 50100 to 50200
# getting from 50200 to 50300
# getting from 50300 to 50400
# getting from 50400 to 50500
# getting from 50500 to 50600
# getting from 50600 to 50700
# getting from 50700 to 50800
# getting from 50800 to 50900
# getting from 50900 to 51000
# getting from 51000 to 51100
# getting from 51100 to 51200
# getting from 51200 to 51300
# getting from 51300 to 51400
# getting from 51400 to 51500
# getting from 51500 to 51600
# getting from 51600 to 51700
# getting from 51700 to 51800
# getting from 51800 to 51900
# getting from 51900 to 52000
# getting from 52000 to 52100
# getting from 52100 to 52200
# getting from 52200 to 52300
# getting from 52300 to 52400
# getting from 52400 to 52500
# getting from 52500 to 52600
# getting from 52600 to 52700
# getting from 52700 to 52800
# getting from 52800 to 52900
# getting from 52900 to 53000
# getting from 53000 to 53100
# getting from 53100 to 53200
# getting from 53200 to 53300
# getting from 53300 to 53400
# getting from 53400 to 53500
# getting from 53500 to 53600
# getting from 53600 to 53700
# getting from 53700 to 53800
# getting from 53800 to 53900
# getting from 53900 to 54000
# getting from 54000 to 54100
# getting from 54100 to 54200
# getting from 54200 to 54300
# getting from 54300 to 54400
# getting from 54400 to 54500
# getting from 54500 to 54600
# getting from 54600 to 54700
# getting from 54700 to 54800
# getting from 54800 to 54900
# getting from 54900 to 55000
# getting from 55000 to 55100
# getting from 55100 to 55200
# getting from 55200 to 55300
# getting from 55300 to 55400
# getting from 55400 to 55500
# getting from 55500 to 55600
# getting from 55600 to 55700
# getting from 55700 to 55800
# getting from 55800 to 55900
# getting from 55900 to 56000
# getting from 56000 to 56100
# getting from 56100 to 56200
# getting from 56200 to 56300
# getting from 56300 to 56400
# getting from 56400 to 56500
# getting from 56500 to 56600
# getting from 56600 to 56700
# getting from 56700 to 56800
# getting from 56800 to 56900
# getting from 56900 to 57000
# getting from 57000 to 57100
# getting from 57100 to 57200
# getting from 57200 to 57300
# getting from 57300 to 57400
# getting from 57400 to 57500
# getting from 57500 to 57600
# getting from 57600 to 57700
# getting from 57700 to 57800
# getting from 57800 to 57900
# getting from 57900 to 58000
# getting from 58000 to 58100
# getting from 58100 to 58200
# getting from 58200 to 58300
# getting from 58300 to 58400
# getting from 58400 to 58500
# getting from 58500 to 58600
# getting from 58600 to 58700
# getting from 58700 to 58800
# getting from 58800 to 58900
# getting from 58900 to 59000
# getting from 59000 to 59100
# getting from 59100 to 59200
# getting from 59200 to 59300
# getting from 59300 to 59400
# getting from 59400 to 59500
# getting from 59500 to 59600
# getting from 59600 to 59700
# getting from 59700 to 59800
# getting from 59800 to 59900
# getting from 59900 to 60000
# getting from 60000 to 60100
# getting from 60100 to 60200
# getting from 60200 to 60300
# getting from 60300 to 60400
# getting from 60400 to 60500
# getting from 60500 to 60600
# getting from 60600 to 60700
# getting from 60700 to 60800
# getting from 60800 to 60900
# getting from 60900 to 61000
# getting from 61000 to 61100
# getting from 61100 to 61200
# getting from 61200 to 61300
# getting from 61300 to 61400
# getting from 61400 to 61500
# getting from 61500 to 61600
# getting from 61600 to 61700
# getting from 61700 to 61800
# getting from 61800 to 61900
# getting from 61900 to 62000
# getting from 62000 to 62100
# getting from 62100 to 62200
# getting from 62200 to 62300
# getting from 62300 to 62400
# getting from 62400 to 62500
# getting from 62500 to 62600
# getting from 62600 to 62700
# getting from 62700 to 62800
# getting from 62800 to 62900
# getting from 62900 to 63000
# getting from 63000 to 63100
# getting from 63100 to 63200
# getting from 63200 to 63300
# getting from 63300 to 63400
# getting from 63400 to 63500
# getting from 63500 to 63600
# getting from 63600 to 63700
# getting from 63700 to 63800
# getting from 63800 to 63900
# getting from 63900 to 64000
# getting from 64000 to 64100
# getting from 64100 to 64200
# getting from 64200 to 64300
# getting from 64300 to 64400
# getting from 64400 to 64500
# getting from 64500 to 64600
# getting from 64600 to 64700
# getting from 64700 to 64800
# getting from 64800 to 64900
# getting from 64900 to 65000
# getting from 65000 to 65100
# getting from 65100 to 65200
# getting from 65200 to 65300
# getting from 65300 to 65400
# getting from 65400 to 65500
# getting from 65500 to 65600
# getting from 65600 to 65700
# getting from 65700 to 65800
# getting from 65800 to 65900
# getting from 65900 to 66000
# getting from 66000 to 66100
# getting from 66100 to 66200
# getting from 66200 to 66300
# getting from 66300 to 66400
# getting from 66400 to 66500
# getting from 66500 to 66600
# getting from 66600 to 66700
# getting from 66700 to 66800
# getting from 66800 to 66900
# getting from 66900 to 67000
# getting from 67000 to 67100
# getting from 67100 to 67200
# getting from 67200 to 67300
# getting from 67300 to 67400
# getting from 67400 to 67500
# getting from 67500 to 67600
# getting from 67600 to 67700
# getting from 67700 to 67800
# getting from 67800 to 67900
# getting from 67900 to 68000
# getting from 68000 to 68100
# getting from 68100 to 68200
# getting from 68200 to 68300
# getting from 68300 to 68400
# getting from 68400 to 68500
# getting from 68500 to 68600
# getting from 68600 to 68700
# getting from 68700 to 68800
# getting from 68800 to 68900
# getting from 68900 to 69000
# getting from 69000 to 69100
# getting from 69100 to 69200
# getting from 69200 to 69300
# getting from 69300 to 69400
# getting from 69400 to 69500
# getting from 69500 to 69600
# getting from 69600 to 69700
# getting from 69700 to 69800
# getting from 69800 to 69900
# getting from 69900 to 70000
# getting from 70000 to 70100
# getting from 70100 to 70200
# getting from 70200 to 70300
# getting from 70300 to 70400
# getting from 70400 to 70500
# getting from 70500 to 70600
# getting from 70600 to 70700
# getting from 70700 to 70800
# getting from 70800 to 70900
# getting from 70900 to 71000
# getting from 71000 to 71100
# getting from 71100 to 71200
# getting from 71200 to 71300
# getting from 71300 to 71400
# getting from 71400 to 71500
# getting from 71500 to 71600
# getting from 71600 to 71700
# getting from 71700 to 71800
# getting from 71800 to 71900
# getting from 71900 to 72000
# getting from 72000 to 72100
# getting from 72100 to 72200
# getting from 72200 to 72300
# getting from 72300 to 72400
# getting from 72400 to 72500
# getting from 72500 to 72600
# getting from 72600 to 72700
# getting from 72700 to 72800
# getting from 72800 to 72900
# getting from 72900 to 73000
# getting from 73000 to 73100
# getting from 73100 to 73200
# getting from 73200 to 73300
# getting from 73300 to 73400
# getting from 73400 to 73500
# getting from 73500 to 73600
# getting from 73600 to 73700
# getting from 73700 to 73800
# getting from 73800 to 73900
# getting from 73900 to 74000
# getting from 74000 to 74100
# getting from 74100 to 74200
# getting from 74200 to 74300
# getting from 74300 to 74400
# getting from 74400 to 74500
# getting from 74500 to 74600
# getting from 74600 to 74700
# getting from 74700 to 74800
# getting from 74800 to 74900
# getting from 74900 to 75000
# getting from 75000 to 75100
# getting from 75100 to 75200
# getting from 75200 to 75300
# getting from 75300 to 75400
# getting from 75400 to 75500
# getting from 75500 to 75600
# getting from 75600 to 75700
# getting from 75700 to 75800
# getting from 75800 to 75900
# getting from 75900 to 76000
# getting from 76000 to 76100
# getting from 76100 to 76200
# getting from 76200 to 76300
# getting from 76300 to 76400
# getting from 76400 to 76500
# getting from 76500 to 76600
# getting from 76600 to 76700
# getting from 76700 to 76800
# getting from 76800 to 76900
# getting from 76900 to 77000
# getting from 77000 to 77100
# getting from 77100 to 77200
# getting from 77200 to 77300
# getting from 77300 to 77400
# getting from 77400 to 77500
# getting from 77500 to 77600
# getting from 77600 to 77700
# getting from 77700 to 77800
# getting from 77800 to 77900
# getting from 77900 to 78000
# getting from 78000 to 78100
# getting from 78100 to 78200
# getting from 78200 to 78300
# getting from 78300 to 78400
# getting from 78400 to 78500
# getting from 78500 to 78600
# getting from 78600 to 78700
# getting from 78700 to 78800
# getting from 78800 to 78900
# getting from 78900 to 79000
# getting from 79000 to 79100
# getting from 79100 to 79200
# getting from 79200 to 79300
# getting from 79300 to 79400
# getting from 79400 to 79500
# getting from 79500 to 79600
# getting from 79600 to 79700
# getting from 79700 to 79800
# getting from 79800 to 79900
# getting from 79900 to 80000
# getting from 80000 to 80100
# getting from 80100 to 80200
# getting from 80200 to 80300
# getting from 80300 to 80400
# getting from 80400 to 80500
# getting from 80500 to 80600
# getting from 80600 to 80700
# getting from 80700 to 80800
# getting from 80800 to 80900
# getting from 80900 to 81000
# getting from 81000 to 81100
# getting from 81100 to 81200
# getting from 81200 to 81300
# getting from 81300 to 81400
# getting from 81400 to 81500
# getting from 81500 to 81600
# getting from 81600 to 81700
# getting from 81700 to 81800
# getting from 81800 to 81900
# getting from 81900 to 82000
# getting from 82000 to 82100
# getting from 82100 to 82200
# getting from 82200 to 82300
# getting from 82300 to 82400
# getting from 82400 to 82500
# getting from 82500 to 82600
# getting from 82600 to 82700
# getting from 82700 to 82800
# getting from 82800 to 82900
# getting from 82900 to 83000
# getting from 83000 to 83100
# getting from 83100 to 83200
# getting from 83200 to 83300
# getting from 83300 to 83400
# getting from 83400 to 83500
# getting from 83500 to 83600
# getting from 83600 to 83700
# getting from 83700 to 83800
# getting from 83800 to 83900
# getting from 83900 to 84000
# getting from 84000 to 84100
# getting from 84100 to 84200
# getting from 84200 to 84300
# getting from 84300 to 84400
# getting from 84400 to 84500
# getting from 84500 to 84600
# getting from 84600 to 84700
# getting from 84700 to 84800
# getting from 84800 to 84900
# getting from 84900 to 85000
# getting from 85000 to 85100
# getting from 85100 to 85200
# getting from 85200 to 85300
# getting from 85300 to 85400
# getting from 85400 to 85500
# getting from 85500 to 85600
# getting from 85600 to 85700
# getting from 85700 to 85800
# getting from 85800 to 85900
# getting from 85900 to 86000
# getting from 86000 to 86100
# getting from 86100 to 86200
# getting from 86200 to 86300
# getting from 86300 to 86400
# getting from 86400 to 86500
# getting from 86500 to 86600
# getting from 86600 to 86700
# getting from 86700 to 86800
# getting from 86800 to 86900
# getting from 86900 to 87000
# getting from 87000 to 87100
# getting from 87100 to 87200
# getting from 87200 to 87300
# getting from 87300 to 87400
# getting from 87400 to 87500
# getting from 87500 to 87600
# getting from 87600 to 87700
# getting from 87700 to 87800
# getting from 87800 to 87900
# getting from 87900 to 88000
# getting from 88000 to 88100
# getting from 88100 to 88200
# getting from 88200 to 88300
# getting from 88300 to 88400
# getting from 88400 to 88500
# getting from 88500 to 88600
# getting from 88600 to 88700
# getting from 88700 to 88800
# getting from 88800 to 88900
# getting from 88900 to 89000
# getting from 89000 to 89100
# getting from 89100 to 89200
# getting from 89200 to 89300
# getting from 89300 to 89400
# getting from 89400 to 89500
# getting from 89500 to 89600
# getting from 89600 to 89700
# getting from 89700 to 89800
# getting from 89800 to 89900
# getting from 89900 to 90000
# getting from 90000 to 90100
# getting from 90100 to 90200
# getting from 90200 to 90300
# getting from 90300 to 90400
# getting from 90400 to 90500
# getting from 90500 to 90600
# getting from 90600 to 90700
# getting from 90700 to 90800
# getting from 90800 to 90900
# getting from 90900 to 91000
# getting from 91000 to 91100
# getting from 91100 to 91200
# getting from 91200 to 91300
# getting from 91300 to 91400
# getting from 91400 to 91500
# getting from 91500 to 91600
# getting from 91600 to 91700
# getting from 91700 to 91800
# getting from 91800 to 91900
# getting from 91900 to 92000
# getting from 92000 to 92100
# getting from 92100 to 92200
# getting from 92200 to 92300
# getting from 92300 to 92400
# getting from 92400 to 92500
# getting from 92500 to 92600
# getting from 92600 to 92700
# getting from 92700 to 92800
# getting from 92800 to 92900
# getting from 92900 to 93000
# getting from 93000 to 93100
# getting from 93100 to 93200
# getting from 93200 to 93300
# getting from 93300 to 93400
# getting from 93400 to 93500
# getting from 93500 to 93600
# getting from 93600 to 93700
# getting from 93700 to 93800
# getting from 93800 to 93900
# getting from 93900 to 94000
# getting from 94000 to 94100
# getting from 94100 to 94200
# getting from 94200 to 94300
# getting from 94300 to 94400
# getting from 94400 to 94500
# getting from 94500 to 94600
# getting from 94600 to 94700
# getting from 94700 to 94800
# getting from 94800 to 94900
# getting from 94900 to 95000
# getting from 95000 to 95100
# getting from 95100 to 95200
# getting from 95200 to 95300
# getting from 95300 to 95400
# getting from 95400 to 95500
# getting from 95500 to 95600
# getting from 95600 to 95700
# getting from 95700 to 95800
# getting from 95800 to 95900
# getting from 95900 to 96000
# getting from 96000 to 96100
# getting from 96100 to 96200
# getting from 96200 to 96300
# getting from 96300 to 96400
# getting from 96400 to 96500
# getting from 96500 to 96600
# getting from 96600 to 96700
# getting from 96700 to 96800
# getting from 96800 to 96900
# getting from 96900 to 97000
# getting from 97000 to 97100
# getting from 97100 to 97200
# getting from 97200 to 97300
# getting from 97300 to 97400
# getting from 97400 to 97500
# getting from 97500 to 97600
# getting from 97600 to 97700
# getting from 97700 to 97800
# getting from 97800 to 97900
# getting from 97900 to 98000
# getting from 98000 to 98100
# getting from 98100 to 98200
# getting from 98200 to 98300
# getting from 98300 to 98400
# getting from 98400 to 98500
# getting from 98500 to 98600
# getting from 98600 to 98700
# getting from 98700 to 98800
# getting from 98800 to 98900
# getting from 98900 to 99000
# getting from 99000 to 99100
# getting from 99100 to 99200
# getting from 99200 to 99300
# getting from 99300 to 99400
# getting from 99400 to 99500
# getting from 99500 to 99600
# getting from 99600 to 99700
# getting from 99700 to 99800
# getting from 99800 to 99900
# getting from 99900 to 100000
# getting from 100000 to 100100
# getting from 100100 to 100200
# getting from 100200 to 100300
# getting from 100300 to 100400
# getting from 100400 to 100500
# getting from 100500 to 100600
# getting from 100600 to 100700
# getting from 100700 to 100800
# getting from 100800 to 100900
# getting from 100900 to 101000
# getting from 101000 to 101100
# getting from 101100 to 101200
# getting from 101200 to 101300
# getting from 101300 to 101400
# getting from 101400 to 101500
# getting from 101500 to 101600
# getting from 101600 to 101700
# getting from 101700 to 101800
# getting from 101800 to 101900
# getting from 101900 to 102000
# getting from 102000 to 102100
# getting from 102100 to 102200
# getting from 102200 to 102300
# getting from 102300 to 102400
# getting from 102400 to 102500
# getting from 102500 to 102600
# getting from 102600 to 102700
# getting from 102700 to 102800
# getting from 102800 to 102900
# getting from 102900 to 103000
# getting from 103000 to 103100
# getting from 103100 to 103200
# getting from 103200 to 103300
# getting from 103300 to 103400
# getting from 103400 to 103500
# getting from 103500 to 103600
# getting from 103600 to 103700
# getting from 103700 to 103800
# getting from 103800 to 103900
# getting from 103900 to 104000
# getting from 104000 to 104100
# getting from 104100 to 104200
# getting from 104200 to 104300
# getting from 104300 to 104400
# getting from 104400 to 104500
# getting from 104500 to 104600
# getting from 104600 to 104700
# getting from 104700 to 104800
# getting from 104800 to 104900
# getting from 104900 to 105000
# getting from 105000 to 105100
# getting from 105100 to 105200
# getting from 105200 to 105300
# getting from 105300 to 105400
# getting from 105400 to 105500
# getting from 105500 to 105600
# getting from 105600 to 105700
# getting from 105700 to 105800
# getting from 105800 to 105900
# getting from 105900 to 106000
# getting from 106000 to 106100
# getting from 106100 to 106200
# getting from 106200 to 106300
# getting from 106300 to 106400
# getting from 106400 to 106500
# getting from 106500 to 106600
# getting from 106600 to 106700
# getting from 106700 to 106800
# getting from 106800 to 106900
# getting from 106900 to 107000
# getting from 107000 to 107100
# getting from 107100 to 107200
# getting from 107200 to 107300
# getting from 107300 to 107400
# getting from 107400 to 107500
# getting from 107500 to 107600
# getting from 107600 to 107700
# getting from 107700 to 107800
# getting from 107800 to 107900
# getting from 107900 to 108000
# getting from 108000 to 108100
# getting from 108100 to 108200
# getting from 108200 to 108300
# getting from 108300 to 108400
# getting from 108400 to 108500
# getting from 108500 to 108600
# getting from 108600 to 108700
# getting from 108700 to 108800
# getting from 108800 to 108900
# getting from 108900 to 109000
# getting from 109000 to 109100
# getting from 109100 to 109200
# getting from 109200 to 109300
# getting from 109300 to 109400
# getting from 109400 to 109500
# getting from 109500 to 109600
# getting from 109600 to 109700
# getting from 109700 to 109800
# getting from 109800 to 109900
# getting from 109900 to 110000
# getting from 110000 to 110100
# getting from 110100 to 110200
# getting from 110200 to 110300
# getting from 110300 to 110400
# getting from 110400 to 110500
# getting from 110500 to 110600
# getting from 110600 to 110700
# getting from 110700 to 110800
# getting from 110800 to 110900
# getting from 110900 to 111000
# getting from 111000 to 111100
# getting from 111100 to 111200
# getting from 111200 to 111300
# getting from 111300 to 111400
# getting from 111400 to 111500
# getting from 111500 to 111600
# getting from 111600 to 111700
# getting from 111700 to 111800
# getting from 111800 to 111900
# getting from 111900 to 112000
# getting from 112000 to 112100
# getting from 112100 to 112200
# getting from 112200 to 112300
# getting from 112300 to 112400
# getting from 112400 to 112500
# getting from 112500 to 112600
# getting from 112600 to 112700
# getting from 112700 to 112800
# getting from 112800 to 112900
# getting from 112900 to 113000
# getting from 113000 to 113100
# getting from 113100 to 113200
# getting from 113200 to 113300
# getting from 113300 to 113400
# getting from 113400 to 113500
# getting from 113500 to 113600
# getting from 113600 to 113700
# getting from 113700 to 113800
# getting from 113800 to 113900
# getting from 113900 to 114000
# getting from 114000 to 114100
# getting from 114100 to 114200
# getting from 114200 to 114300
# getting from 114300 to 114400
# getting from 114400 to 114500
# getting from 114500 to 114600
# getting from 114600 to 114700
# getting from 114700 to 114800
# getting from 114800 to 114900
# getting from 114900 to 115000
# getting from 115000 to 115100
# getting from 115100 to 115200
# getting from 115200 to 115300
# getting from 115300 to 115400
# getting from 115400 to 115500
# getting from 115500 to 115600
# getting from 115600 to 115700
# getting from 115700 to 115800
# getting from 115800 to 115900
# getting from 115900 to 116000
# getting from 116000 to 116100
# getting from 116100 to 116200
# getting from 116200 to 116300
# getting from 116300 to 116400
# getting from 116400 to 116500
# getting from 116500 to 116600
# getting from 116600 to 116700
# getting from 116700 to 116800
# getting from 116800 to 116900
# getting from 116900 to 117000
# getting from 117000 to 117100
# getting from 117100 to 117200
# getting from 117200 to 117300
# getting from 117300 to 117400
# getting from 117400 to 117500
# getting from 117500 to 117600
# getting from 117600 to 117700
# getting from 117700 to 117800
# getting from 117800 to 117900
# getting from 117900 to 118000
# getting from 118000 to 118100
# getting from 118100 to 118200
# getting from 118200 to 118300
# getting from 118300 to 118400
# getting from 118400 to 118500
# getting from 118500 to 118600
# getting from 118600 to 118700
# getting from 118700 to 118800
# getting from 118800 to 118900
# getting from 118900 to 119000
# getting from 119000 to 119100
# getting from 119100 to 119200
# getting from 119200 to 119300
# getting from 119300 to 119400
# getting from 119400 to 119500
# getting from 119500 to 119600
# getting from 119600 to 119700
# getting from 119700 to 119800
# getting from 119800 to 119900
# getting from 119900 to 120000
# getting from 120000 to 120100
# getting from 120100 to 120200
# getting from 120200 to 120300
# getting from 120300 to 120400
# getting from 120400 to 120500
# getting from 120500 to 120600
# getting from 120600 to 120700
# getting from 120700 to 120800
# getting from 120800 to 120900
# getting from 120900 to 121000
# getting from 121000 to 121100
# getting from 121100 to 121200
# getting from 121200 to 121300
# getting from 121300 to 121400
# getting from 121400 to 121500
# getting from 121500 to 121600
# getting from 121600 to 121700
# getting from 121700 to 121800
# getting from 121800 to 121900
# getting from 121900 to 122000
# getting from 122000 to 122100
# getting from 122100 to 122200
# getting from 122200 to 122300
# getting from 122300 to 122400
# getting from 122400 to 122500
# getting from 122500 to 122600
# getting from 122600 to 122700
# getting from 122700 to 122800
# getting from 122800 to 122900
# getting from 122900 to 123000
# getting from 123000 to 123100
# getting from 123100 to 123200
# getting from 123200 to 123300
# getting from 123300 to 123400
# getting from 123400 to 123500
# getting from 123500 to 123600
# getting from 123600 to 123700
# getting from 123700 to 123800
# getting from 123800 to 123900
# getting from 123900 to 124000
# getting from 124000 to 124100
# getting from 124100 to 124200
# getting from 124200 to 124300
# getting from 124300 to 124400
# getting from 124400 to 124500
# getting from 124500 to 124600
# getting from 124600 to 124700
# getting from 124700 to 124800
# getting from 124800 to 124900
# getting from 124900 to 125000
# getting from 125000 to 125100
# getting from 125100 to 125200
# getting from 125200 to 125300
# getting from 125300 to 125400
# getting from 125400 to 125500
# getting from 125500 to 125600
# getting from 125600 to 125700
# getting from 125700 to 125800
# getting from 125800 to 125900
# getting from 125900 to 126000
# getting from 126000 to 126100
# getting from 126100 to 126200
# getting from 126200 to 126300
# getting from 126300 to 126400
# getting from 126400 to 126500
# getting from 126500 to 126600
# getting from 126600 to 126700
# getting from 126700 to 126800
# getting from 126800 to 126900
# getting from 126900 to 127000
# getting from 127000 to 127100
# getting from 127100 to 127200
# getting from 127200 to 127300
# getting from 127300 to 127400
# getting from 127400 to 127500
# getting from 127500 to 127600
# getting from 127600 to 127700
# getting from 127700 to 127800
# getting from 127800 to 127900
# getting from 127900 to 128000
# getting from 128000 to 128100
# getting from 128100 to 128200
# getting from 128200 to 128300
# getting from 128300 to 128400
# getting from 128400 to 128500
# getting from 128500 to 128600
# getting from 128600 to 128700
# getting from 128700 to 128800
# getting from 128800 to 128900
# getting from 128900 to 129000
# getting from 129000 to 129100
# getting from 129100 to 129200
# getting from 129200 to 129300
# getting from 129300 to 129400
# getting from 129400 to 129500
# getting from 129500 to 129600
# getting from 129600 to 129700
# getting from 129700 to 129800
# getting from 129800 to 129900
# getting from 129900 to 130000
# getting from 130000 to 130100
# getting from 130100 to 130200
# getting from 130200 to 130300
# getting from 130300 to 130400
# getting from 130400 to 130500
# getting from 130500 to 130600
# getting from 130600 to 130700
# getting from 130700 to 130800
# getting from 130800 to 130900
# getting from 130900 to 131000
# getting from 131000 to 131100
# getting from 131100 to 131200
# getting from 131200 to 131300
# getting from 131300 to 131400
# getting from 131400 to 131500
# getting from 131500 to 131600
# getting from 131600 to 131700
# getting from 131700 to 131800
# getting from 131800 to 131900
# getting from 131900 to 132000
# getting from 132000 to 132100
# getting from 132100 to 132200
# getting from 132200 to 132300
# getting from 132300 to 132400
# getting from 132400 to 132500
# getting from 132500 to 132600
# getting from 132600 to 132700
# getting from 132700 to 132800
# getting from 132800 to 132900
# getting from 132900 to 133000

# %% [markdown]
# * We use the same method to acquire the track features, with the use of the `sp.tracks` method.
# * For this API endpoint Spotify permits 50 ids per batch.

# %%
def get_track_features(track_ids):
    track_features_dict = {}
    start = 0
    num_tracks = 50

    while start < len(track_ids):
        print(f'getting from {start} to {start+num_tracks}')
        try:
            tracks_batch = track_ids[start:start+num_tracks]
            features_batch = sp.tracks(tracks_batch)
            track_features_dict.update({ track_id : {'explicit': features['explicit'], 'release_date': features['album']['release_date']} 
                            for track_id, features in zip(tracks_batch, features_batch['tracks']) })
        except Exception:
            print('error:', start)
        start += num_tracks
        
    return track_features_dict

# %%
track_features = get_track_features(all_track_ids)
# Out:
# getting from 0 to 50
# getting from 50 to 100
# getting from 100 to 150
# getting from 150 to 200
# getting from 200 to 250
# getting from 250 to 300
# getting from 300 to 350
# getting from 350 to 400
# getting from 400 to 450
# getting from 450 to 500
# getting from 500 to 550
# getting from 550 to 600
# getting from 600 to 650
# getting from 650 to 700
# getting from 700 to 750
# getting from 750 to 800
# getting from 800 to 850
# getting from 850 to 900
# getting from 900 to 950
# getting from 950 to 1000
# getting from 1000 to 1050
# getting from 1050 to 1100
# getting from 1100 to 1150
# getting from 1150 to 1200
# getting from 1200 to 1250
# getting from 1250 to 1300
# getting from 1300 to 1350
# getting from 1350 to 1400
# getting from 1400 to 1450
# getting from 1450 to 1500
# getting from 1500 to 1550
# getting from 1550 to 1600
# getting from 1600 to 1650
# getting from 1650 to 1700
# getting from 1700 to 1750
# getting from 1750 to 1800
# getting from 1800 to 1850
# getting from 1850 to 1900
# getting from 1900 to 1950
# getting from 1950 to 2000
# getting from 2000 to 2050
# getting from 2050 to 2100
# getting from 2100 to 2150
# getting from 2150 to 2200
# getting from 2200 to 2250
# getting from 2250 to 2300
# getting from 2300 to 2350
# getting from 2350 to 2400
# getting from 2400 to 2450
# getting from 2450 to 2500
# getting from 2500 to 2550
# getting from 2550 to 2600
# getting from 2600 to 2650
# getting from 2650 to 2700
# getting from 2700 to 2750
# getting from 2750 to 2800
# getting from 2800 to 2850
# getting from 2850 to 2900
# getting from 2900 to 2950
# getting from 2950 to 3000
# getting from 3000 to 3050
# getting from 3050 to 3100
# getting from 3100 to 3150
# getting from 3150 to 3200
# getting from 3200 to 3250
# getting from 3250 to 3300
# getting from 3300 to 3350
# getting from 3350 to 3400
# getting from 3400 to 3450
# getting from 3450 to 3500
# getting from 3500 to 3550
# getting from 3550 to 3600
# getting from 3600 to 3650
# getting from 3650 to 3700
# getting from 3700 to 3750
# getting from 3750 to 3800
# getting from 3800 to 3850
# getting from 3850 to 3900
# getting from 3900 to 3950
# getting from 3950 to 4000
# getting from 4000 to 4050
# getting from 4050 to 4100
# getting from 4100 to 4150
# getting from 4150 to 4200
# getting from 4200 to 4250
# getting from 4250 to 4300
# getting from 4300 to 4350
# getting from 4350 to 4400
# getting from 4400 to 4450
# getting from 4450 to 4500
# getting from 4500 to 4550
# getting from 4550 to 4600
# getting from 4600 to 4650
# getting from 4650 to 4700
# getting from 4700 to 4750
# getting from 4750 to 4800
# getting from 4800 to 4850
# getting from 4850 to 4900
# getting from 4900 to 4950
# getting from 4950 to 5000
# getting from 5000 to 5050
# getting from 5050 to 5100
# getting from 5100 to 5150
# getting from 5150 to 5200
# getting from 5200 to 5250
# getting from 5250 to 5300
# getting from 5300 to 5350
# getting from 5350 to 5400
# getting from 5400 to 5450
# getting from 5450 to 5500
# getting from 5500 to 5550
# getting from 5550 to 5600
# getting from 5600 to 5650
# getting from 5650 to 5700
# getting from 5700 to 5750
# getting from 5750 to 5800
# getting from 5800 to 5850
# getting from 5850 to 5900
# getting from 5900 to 5950
# getting from 5950 to 6000
# getting from 6000 to 6050
# getting from 6050 to 6100
# getting from 6100 to 6150
# getting from 6150 to 6200
# getting from 6200 to 6250
# getting from 6250 to 6300
# getting from 6300 to 6350
# getting from 6350 to 6400
# getting from 6400 to 6450
# getting from 6450 to 6500
# getting from 6500 to 6550
# getting from 6550 to 6600
# getting from 6600 to 6650
# getting from 6650 to 6700
# getting from 6700 to 6750
# getting from 6750 to 6800
# getting from 6800 to 6850
# getting from 6850 to 6900
# getting from 6900 to 6950
# getting from 6950 to 7000
# getting from 7000 to 7050
# getting from 7050 to 7100
# getting from 7100 to 7150
# getting from 7150 to 7200
# getting from 7200 to 7250
# getting from 7250 to 7300
# getting from 7300 to 7350
# getting from 7350 to 7400
# getting from 7400 to 7450
# getting from 7450 to 7500
# getting from 7500 to 7550
# getting from 7550 to 7600
# getting from 7600 to 7650
# getting from 7650 to 7700
# getting from 7700 to 7750
# getting from 7750 to 7800
# getting from 7800 to 7850
# getting from 7850 to 7900
# getting from 7900 to 7950
# getting from 7950 to 8000
# getting from 8000 to 8050
# getting from 8050 to 8100
# getting from 8100 to 8150
# getting from 8150 to 8200
# getting from 8200 to 8250
# getting from 8250 to 8300
# getting from 8300 to 8350
# getting from 8350 to 8400
# getting from 8400 to 8450
# getting from 8450 to 8500
# getting from 8500 to 8550
# getting from 8550 to 8600
# getting from 8600 to 8650
# getting from 8650 to 8700
# getting from 8700 to 8750
# getting from 8750 to 8800
# getting from 8800 to 8850
# getting from 8850 to 8900
# getting from 8900 to 8950
# getting from 8950 to 9000
# getting from 9000 to 9050
# getting from 9050 to 9100
# getting from 9100 to 9150
# getting from 9150 to 9200
# getting from 9200 to 9250
# getting from 9250 to 9300
# getting from 9300 to 9350
# getting from 9350 to 9400
# getting from 9400 to 9450
# getting from 9450 to 9500
# getting from 9500 to 9550
# getting from 9550 to 9600
# getting from 9600 to 9650
# getting from 9650 to 9700
# getting from 9700 to 9750
# getting from 9750 to 9800
# getting from 9800 to 9850
# getting from 9850 to 9900
# getting from 9900 to 9950
# getting from 9950 to 10000
# getting from 10000 to 10050
# getting from 10050 to 10100
# getting from 10100 to 10150
# getting from 10150 to 10200
# getting from 10200 to 10250
# getting from 10250 to 10300
# getting from 10300 to 10350
# getting from 10350 to 10400
# getting from 10400 to 10450
# getting from 10450 to 10500
# getting from 10500 to 10550
# getting from 10550 to 10600
# getting from 10600 to 10650
# getting from 10650 to 10700
# getting from 10700 to 10750
# getting from 10750 to 10800
# getting from 10800 to 10850
# getting from 10850 to 10900
# getting from 10900 to 10950
# getting from 10950 to 11000
# getting from 11000 to 11050
# getting from 11050 to 11100
# getting from 11100 to 11150
# getting from 11150 to 11200
# getting from 11200 to 11250
# getting from 11250 to 11300
# getting from 11300 to 11350
# getting from 11350 to 11400
# getting from 11400 to 11450
# getting from 11450 to 11500
# getting from 11500 to 11550
# getting from 11550 to 11600
# getting from 11600 to 11650
# getting from 11650 to 11700
# getting from 11700 to 11750
# getting from 11750 to 11800
# getting from 11800 to 11850
# getting from 11850 to 11900
# getting from 11900 to 11950
# getting from 11950 to 12000
# getting from 12000 to 12050
# getting from 12050 to 12100
# getting from 12100 to 12150
# getting from 12150 to 12200
# getting from 12200 to 12250
# getting from 12250 to 12300
# getting from 12300 to 12350
# getting from 12350 to 12400
# getting from 12400 to 12450
# getting from 12450 to 12500
# getting from 12500 to 12550
# getting from 12550 to 12600
# getting from 12600 to 12650
# getting from 12650 to 12700
# getting from 12700 to 12750
# getting from 12750 to 12800
# getting from 12800 to 12850
# getting from 12850 to 12900
# getting from 18800 to 18850
# getting from 18850 to 18900
# getting from 18900 to 18950
# getting from 18950 to 19000
# getting from 19000 to 19050
# getting from 19050 to 19100
# getting from 19100 to 19150
# getting from 19150 to 19200
# getting from 19200 to 19250
# getting from 19250 to 19300
# getting from 19300 to 19350
# getting from 19350 to 19400
# getting from 19400 to 19450
# getting from 19450 to 19500
# getting from 19500 to 19550
# getting from 19550 to 19600
# getting from 19600 to 19650
# getting from 19650 to 19700
# getting from 19700 to 19750
# getting from 19750 to 19800
# getting from 19800 to 19850
# getting from 19850 to 19900
# getting from 19900 to 19950
# getting from 19950 to 20000
# getting from 20000 to 20050
# getting from 20050 to 20100
# getting from 20100 to 20150
# getting from 20150 to 20200
# getting from 20200 to 20250
# getting from 20250 to 20300
# getting from 20300 to 20350
# getting from 20350 to 20400
# getting from 20400 to 20450
# getting from 20450 to 20500
# getting from 20500 to 20550
# getting from 20550 to 20600
# getting from 20600 to 20650
# getting from 20650 to 20700
# getting from 20700 to 20750
# getting from 20750 to 20800
# getting from 20800 to 20850
# getting from 20850 to 20900
# getting from 20900 to 20950
# getting from 20950 to 21000
# getting from 21000 to 21050
# getting from 21050 to 21100
# getting from 21100 to 21150
# getting from 21150 to 21200
# getting from 21200 to 21250
# getting from 21250 to 21300
# getting from 21300 to 21350
# getting from 21350 to 21400
# getting from 21400 to 21450
# getting from 21450 to 21500
# getting from 21500 to 21550
# getting from 21550 to 21600
# getting from 21600 to 21650
# getting from 21650 to 21700
# getting from 21700 to 21750
# getting from 21750 to 21800
# getting from 21800 to 21850
# getting from 21850 to 21900
# getting from 21900 to 21950
# getting from 21950 to 22000
# getting from 22000 to 22050
# getting from 22050 to 22100
# getting from 22100 to 22150
# getting from 22150 to 22200
# getting from 22200 to 22250
# getting from 22250 to 22300
# getting from 22300 to 22350
# getting from 22350 to 22400
# getting from 22400 to 22450
# getting from 22450 to 22500
# getting from 22500 to 22550
# getting from 22550 to 22600
# getting from 22600 to 22650
# getting from 22650 to 22700
# getting from 22700 to 22750
# getting from 22750 to 22800
# getting from 22800 to 22850
# getting from 22850 to 22900
# getting from 22900 to 22950
# getting from 22950 to 23000
# getting from 23000 to 23050
# getting from 23050 to 23100
# getting from 23100 to 23150
# getting from 23150 to 23200
# getting from 23200 to 23250
# getting from 23250 to 23300
# getting from 23300 to 23350
# getting from 23350 to 23400
# getting from 23400 to 23450
# getting from 23450 to 23500
# getting from 23500 to 23550
# getting from 23550 to 23600
# getting from 23600 to 23650
# getting from 23650 to 23700
# getting from 23700 to 23750
# getting from 23750 to 23800
# getting from 23800 to 23850
# getting from 23850 to 23900
# getting from 23900 to 23950
# getting from 23950 to 24000
# getting from 24000 to 24050
# getting from 24050 to 24100
# getting from 24100 to 24150
# getting from 24150 to 24200
# getting from 24200 to 24250
# getting from 24250 to 24300
# getting from 24300 to 24350
# getting from 24350 to 24400
# getting from 24400 to 24450
# getting from 24450 to 24500
# getting from 24500 to 24550
# getting from 24550 to 24600
# getting from 24600 to 24650
# getting from 24650 to 24700
# getting from 30650 to 30700
# getting from 30700 to 30750
# getting from 30750 to 30800
# getting from 30800 to 30850
# getting from 30850 to 30900
# getting from 30900 to 30950
# getting from 30950 to 31000
# getting from 31000 to 31050
# getting from 31050 to 31100
# getting from 31100 to 31150
# getting from 31150 to 31200
# getting from 31200 to 31250
# getting from 31250 to 31300
# getting from 31300 to 31350
# getting from 31350 to 31400
# getting from 31400 to 31450
# getting from 31450 to 31500
# getting from 31500 to 31550
# getting from 31550 to 31600
# getting from 31600 to 31650
# getting from 31650 to 31700
# getting from 31700 to 31750
# getting from 31750 to 31800
# getting from 31800 to 31850
# getting from 31850 to 31900
# getting from 31900 to 31950
# getting from 31950 to 32000
# getting from 32000 to 32050
# getting from 32050 to 32100
# getting from 32100 to 32150
# getting from 32150 to 32200
# getting from 32200 to 32250
# getting from 32250 to 32300
# getting from 32300 to 32350
# getting from 32350 to 32400
# getting from 32400 to 32450
# getting from 32450 to 32500
# getting from 32500 to 32550
# getting from 32550 to 32600
# getting from 32600 to 32650
# getting from 32650 to 32700
# getting from 32700 to 32750
# getting from 32750 to 32800
# getting from 32800 to 32850
# getting from 32850 to 32900
# getting from 32900 to 32950
# getting from 32950 to 33000
# getting from 33000 to 33050
# getting from 33050 to 33100
# getting from 33100 to 33150
# getting from 33150 to 33200
# getting from 33200 to 33250
# getting from 33250 to 33300
# getting from 33300 to 33350
# getting from 33350 to 33400
# getting from 33400 to 33450
# getting from 33450 to 33500
# getting from 33500 to 33550
# getting from 33550 to 33600
# getting from 33600 to 33650
# getting from 33650 to 33700
# getting from 33700 to 33750
# getting from 33750 to 33800
# getting from 33800 to 33850
# getting from 33850 to 33900
# getting from 33900 to 33950
# getting from 33950 to 34000
# getting from 34000 to 34050
# getting from 34050 to 34100
# getting from 34100 to 34150
# getting from 34150 to 34200
# getting from 34200 to 34250
# getting from 34250 to 34300
# getting from 34300 to 34350
# getting from 34350 to 34400
# getting from 34400 to 34450
# getting from 34450 to 34500
# getting from 34500 to 34550
# getting from 34550 to 34600
# getting from 34600 to 34650
# getting from 34650 to 34700
# getting from 34700 to 34750
# getting from 34750 to 34800
# getting from 34800 to 34850
# getting from 34850 to 34900
# getting from 34900 to 34950
# getting from 34950 to 35000
# getting from 35000 to 35050
# getting from 35050 to 35100
# getting from 35100 to 35150
# getting from 35150 to 35200
# getting from 35200 to 35250
# getting from 35250 to 35300
# getting from 35300 to 35350
# getting from 35350 to 35400
# getting from 35400 to 35450
# getting from 35450 to 35500
# getting from 35500 to 35550
# getting from 35550 to 35600
# getting from 35600 to 35650
# getting from 35650 to 35700
# getting from 35700 to 35750
# getting from 35750 to 35800
# getting from 35800 to 35850
# getting from 35850 to 35900
# getting from 35900 to 35950
# getting from 35950 to 36000
# getting from 36000 to 36050
# getting from 36050 to 36100
# getting from 36100 to 36150
# getting from 36150 to 36200
# getting from 36200 to 36250
# getting from 36250 to 36300
# getting from 36300 to 36350
# getting from 36350 to 36400
# getting from 36400 to 36450
# getting from 36450 to 36500
# getting from 36500 to 36550
# getting from 36550 to 36600
# getting from 36600 to 36650
# getting from 36650 to 36700
# getting from 36700 to 36750
# getting from 36750 to 36800
# getting from 36800 to 36850
# getting from 36850 to 36900
# getting from 36900 to 36950
# getting from 36950 to 37000
# getting from 37000 to 37050
# getting from 37050 to 37100
# getting from 37100 to 37150
# getting from 37150 to 37200
# getting from 37200 to 37250
# getting from 37250 to 37300
# getting from 37300 to 37350
# getting from 37350 to 37400
# getting from 37400 to 37450
# getting from 37450 to 37500
# getting from 37500 to 37550
# getting from 37550 to 37600
# getting from 37600 to 37650
# getting from 37650 to 37700
# getting from 37700 to 37750
# getting from 37750 to 37800
# getting from 37800 to 37850
# getting from 37850 to 37900
# getting from 37900 to 37950
# getting from 37950 to 38000
# getting from 38000 to 38050
# getting from 38050 to 38100
# getting from 38100 to 38150
# getting from 38150 to 38200
# getting from 38200 to 38250
# getting from 38250 to 38300
# getting from 38300 to 38350
# getting from 38350 to 38400
# getting from 38400 to 38450
# getting from 38450 to 38500
# getting from 38500 to 38550
# getting from 38550 to 38600
# getting from 38600 to 38650
# getting from 38650 to 38700
# getting from 38700 to 38750
# getting from 38750 to 38800
# getting from 38800 to 38850
# getting from 38850 to 38900
# getting from 38900 to 38950
# getting from 38950 to 39000
# getting from 39000 to 39050
# getting from 39050 to 39100
# getting from 39100 to 39150
# getting from 39150 to 39200
# getting from 39200 to 39250
# getting from 39250 to 39300
# getting from 39300 to 39350
# getting from 39350 to 39400
# getting from 39400 to 39450
# getting from 39450 to 39500
# getting from 39500 to 39550
# getting from 39550 to 39600
# getting from 39600 to 39650
# getting from 39650 to 39700
# getting from 39700 to 39750
# getting from 39750 to 39800
# getting from 39800 to 39850
# getting from 39850 to 39900
# getting from 39900 to 39950
# getting from 39950 to 40000
# getting from 40000 to 40050
# getting from 40050 to 40100
# getting from 40100 to 40150
# getting from 40150 to 40200
# getting from 40200 to 40250
# getting from 40250 to 40300
# getting from 40300 to 40350
# getting from 40350 to 40400
# getting from 40400 to 40450
# getting from 40450 to 40500
# getting from 40500 to 40550
# getting from 40550 to 40600
# getting from 40600 to 40650
# getting from 40650 to 40700
# getting from 40700 to 40750
# getting from 40750 to 40800
# getting from 40800 to 40850
# getting from 40850 to 40900
# getting from 40900 to 40950
# getting from 40950 to 41000
# getting from 41000 to 41050
# getting from 41050 to 41100
# getting from 41100 to 41150
# getting from 41150 to 41200
# getting from 41200 to 41250
# getting from 41250 to 41300
# getting from 41300 to 41350
# getting from 41350 to 41400
# getting from 41400 to 41450
# getting from 41450 to 41500
# getting from 41500 to 41550
# getting from 41550 to 41600
# getting from 41600 to 41650
# getting from 41650 to 41700
# getting from 41700 to 41750
# getting from 41750 to 41800
# getting from 41800 to 41850
# getting from 41850 to 41900
# getting from 41900 to 41950
# getting from 41950 to 42000
# getting from 42000 to 42050
# getting from 42050 to 42100
# getting from 42100 to 42150
# getting from 42150 to 42200
# getting from 42200 to 42250
# getting from 42250 to 42300
# getting from 42300 to 42350
# getting from 42350 to 42400
# getting from 42400 to 42450
# getting from 42450 to 42500
# getting from 48400 to 48450
# getting from 48450 to 48500
# getting from 48500 to 48550
# getting from 48550 to 48600
# getting from 48600 to 48650
# getting from 48650 to 48700
# getting from 48700 to 48750
# getting from 48750 to 48800
# getting from 48800 to 48850
# getting from 48850 to 48900
# getting from 48900 to 48950
# getting from 48950 to 49000
# getting from 49000 to 49050
# getting from 49050 to 49100
# getting from 49100 to 49150
# getting from 49150 to 49200
# getting from 49200 to 49250
# getting from 49250 to 49300
# getting from 49300 to 49350
# getting from 49350 to 49400
# getting from 49400 to 49450
# getting from 49450 to 49500
# getting from 49500 to 49550
# getting from 49550 to 49600
# getting from 49600 to 49650
# getting from 49650 to 49700
# getting from 49700 to 49750
# getting from 49750 to 49800
# getting from 49800 to 49850
# getting from 49850 to 49900
# getting from 49900 to 49950
# getting from 49950 to 50000
# getting from 50000 to 50050
# getting from 50050 to 50100
# getting from 50100 to 50150
# getting from 50150 to 50200
# getting from 50200 to 50250
# getting from 50250 to 50300
# getting from 50300 to 50350
# getting from 50350 to 50400
# getting from 50400 to 50450
# getting from 50450 to 50500
# getting from 50500 to 50550
# getting from 50550 to 50600
# getting from 50600 to 50650
# getting from 50650 to 50700
# getting from 50700 to 50750
# getting from 50750 to 50800
# getting from 50800 to 50850
# getting from 50850 to 50900
# getting from 50900 to 50950
# getting from 50950 to 51000
# getting from 51000 to 51050
# getting from 51050 to 51100
# getting from 51100 to 51150
# getting from 51150 to 51200
# getting from 51200 to 51250
# getting from 51250 to 51300
# getting from 51300 to 51350
# getting from 51350 to 51400
# getting from 51400 to 51450
# getting from 51450 to 51500
# getting from 51500 to 51550
# getting from 51550 to 51600
# getting from 51600 to 51650
# getting from 51650 to 51700
# getting from 51700 to 51750
# getting from 51750 to 51800
# getting from 51800 to 51850
# getting from 51850 to 51900
# getting from 51900 to 51950
# getting from 51950 to 52000
# getting from 52000 to 52050
# getting from 52050 to 52100
# getting from 52100 to 52150
# getting from 52150 to 52200
# getting from 52200 to 52250
# getting from 52250 to 52300
# getting from 52300 to 52350
# getting from 52350 to 52400
# getting from 52400 to 52450
# getting from 52450 to 52500
# getting from 52500 to 52550
# getting from 52550 to 52600
# getting from 52600 to 52650
# getting from 52650 to 52700
# getting from 52700 to 52750
# getting from 52750 to 52800
# getting from 52800 to 52850
# getting from 52850 to 52900
# getting from 52900 to 52950
# getting from 52950 to 53000
# getting from 53000 to 53050
# getting from 53050 to 53100
# getting from 53100 to 53150
# getting from 53150 to 53200
# getting from 53200 to 53250
# getting from 53250 to 53300
# getting from 53300 to 53350
# getting from 53350 to 53400
# getting from 53400 to 53450
# getting from 53450 to 53500
# getting from 53500 to 53550
# getting from 53550 to 53600
# getting from 53600 to 53650
# getting from 53650 to 53700
# getting from 53700 to 53750
# getting from 53750 to 53800
# getting from 53800 to 53850
# getting from 53850 to 53900
# getting from 53900 to 53950
# getting from 53950 to 54000
# getting from 54000 to 54050
# getting from 54050 to 54100
# getting from 54100 to 54150
# getting from 54150 to 54200
# getting from 54200 to 54250
# getting from 54250 to 54300
# getting from 60250 to 60300
# getting from 60300 to 60350
# getting from 60350 to 60400
# getting from 60400 to 60450
# getting from 60450 to 60500
# getting from 60500 to 60550
# getting from 60550 to 60600
# getting from 60600 to 60650
# getting from 60650 to 60700
# getting from 60700 to 60750
# getting from 60750 to 60800
# getting from 60800 to 60850
# getting from 60850 to 60900
# getting from 60900 to 60950
# getting from 60950 to 61000
# getting from 61000 to 61050
# getting from 61050 to 61100
# getting from 61100 to 61150
# getting from 61150 to 61200
# getting from 61200 to 61250
# getting from 61250 to 61300
# getting from 61300 to 61350
# getting from 61350 to 61400
# getting from 61400 to 61450
# getting from 61450 to 61500
# getting from 61500 to 61550
# getting from 61550 to 61600
# getting from 61600 to 61650
# getting from 61650 to 61700
# getting from 61700 to 61750
# getting from 61750 to 61800
# getting from 61800 to 61850
# getting from 61850 to 61900
# getting from 61900 to 61950
# getting from 61950 to 62000
# getting from 62000 to 62050
# getting from 62050 to 62100
# getting from 62100 to 62150
# getting from 62150 to 62200
# getting from 62200 to 62250
# getting from 62250 to 62300
# getting from 62300 to 62350
# getting from 62350 to 62400
# getting from 62400 to 62450
# getting from 62450 to 62500
# getting from 62500 to 62550
# getting from 62550 to 62600
# getting from 62600 to 62650
# getting from 62650 to 62700
# getting from 62700 to 62750
# getting from 62750 to 62800
# getting from 62800 to 62850
# getting from 62850 to 62900
# getting from 62900 to 62950
# getting from 62950 to 63000
# getting from 63000 to 63050
# getting from 63050 to 63100
# getting from 63100 to 63150
# getting from 63150 to 63200
# getting from 63200 to 63250
# getting from 63250 to 63300
# getting from 63300 to 63350
# getting from 63350 to 63400
# getting from 63400 to 63450
# getting from 63450 to 63500
# getting from 63500 to 63550
# getting from 63550 to 63600
# getting from 63600 to 63650
# getting from 63650 to 63700
# getting from 63700 to 63750
# getting from 63750 to 63800
# getting from 63800 to 63850
# getting from 63850 to 63900
# getting from 63900 to 63950
# getting from 63950 to 64000
# getting from 64000 to 64050
# getting from 64050 to 64100
# getting from 64100 to 64150
# getting from 64150 to 64200
# getting from 64200 to 64250
# getting from 64250 to 64300
# getting from 64300 to 64350
# getting from 64350 to 64400
# getting from 64400 to 64450
# getting from 64450 to 64500
# getting from 64500 to 64550
# getting from 64550 to 64600
# getting from 64600 to 64650
# getting from 64650 to 64700
# getting from 64700 to 64750
# getting from 64750 to 64800
# getting from 64800 to 64850
# getting from 64850 to 64900
# getting from 64900 to 64950
# getting from 64950 to 65000
# getting from 65000 to 65050
# getting from 65050 to 65100
# getting from 65100 to 65150
# getting from 65150 to 65200
# getting from 65200 to 65250
# getting from 65250 to 65300
# getting from 65300 to 65350
# getting from 65350 to 65400
# getting from 65400 to 65450
# getting from 65450 to 65500
# getting from 65500 to 65550
# getting from 65550 to 65600
# getting from 65600 to 65650
# getting from 65650 to 65700
# getting from 65700 to 65750
# getting from 65750 to 65800
# getting from 65800 to 65850
# getting from 65850 to 65900
# getting from 65900 to 65950
# getting from 65950 to 66000
# getting from 66000 to 66050
# getting from 66050 to 66100
# getting from 66100 to 66150
# getting from 72050 to 72100
# getting from 72100 to 72150
# getting from 72150 to 72200
# getting from 72200 to 72250
# getting from 72250 to 72300
# getting from 72300 to 72350
# getting from 72350 to 72400
# getting from 72400 to 72450
# getting from 72450 to 72500
# getting from 72500 to 72550
# getting from 72550 to 72600
# getting from 72600 to 72650
# getting from 72650 to 72700
# getting from 72700 to 72750
# getting from 72750 to 72800
# getting from 72800 to 72850
# getting from 72850 to 72900
# getting from 72900 to 72950
# getting from 72950 to 73000
# getting from 73000 to 73050
# getting from 73050 to 73100
# getting from 73100 to 73150
# getting from 73150 to 73200
# getting from 73200 to 73250
# getting from 73250 to 73300
# getting from 73300 to 73350
# getting from 73350 to 73400
# getting from 73400 to 73450
# getting from 73450 to 73500
# getting from 73500 to 73550
# getting from 73550 to 73600
# getting from 73600 to 73650
# getting from 73650 to 73700
# getting from 73700 to 73750
# getting from 73750 to 73800
# getting from 73800 to 73850
# getting from 73850 to 73900
# getting from 73900 to 73950
# getting from 73950 to 74000
# getting from 74000 to 74050
# getting from 74050 to 74100
# getting from 74100 to 74150
# getting from 74150 to 74200
# getting from 74200 to 74250
# getting from 74250 to 74300
# getting from 74300 to 74350
# getting from 74350 to 74400
# getting from 74400 to 74450
# getting from 74450 to 74500
# getting from 74500 to 74550
# getting from 74550 to 74600
# getting from 74600 to 74650
# getting from 74650 to 74700
# getting from 74700 to 74750
# getting from 74750 to 74800
# getting from 74800 to 74850
# getting from 74850 to 74900
# getting from 74900 to 74950
# getting from 74950 to 75000
# getting from 75000 to 75050
# getting from 75050 to 75100
# getting from 75100 to 75150
# getting from 75150 to 75200
# getting from 75200 to 75250
# getting from 75250 to 75300
# getting from 75300 to 75350
# getting from 75350 to 75400
# getting from 75400 to 75450
# getting from 75450 to 75500
# getting from 75500 to 75550
# getting from 75550 to 75600
# getting from 75600 to 75650
# getting from 75650 to 75700
# getting from 75700 to 75750
# getting from 75750 to 75800
# getting from 75800 to 75850
# getting from 75850 to 75900
# getting from 75900 to 75950
# getting from 75950 to 76000
# getting from 76000 to 76050
# getting from 76050 to 76100
# getting from 76100 to 76150
# getting from 76150 to 76200
# getting from 76200 to 76250
# getting from 76250 to 76300
# getting from 76300 to 76350
# getting from 76350 to 76400
# getting from 76400 to 76450
# getting from 76450 to 76500
# getting from 76500 to 76550
# getting from 76550 to 76600
# getting from 76600 to 76650
# getting from 76650 to 76700
# getting from 76700 to 76750
# getting from 76750 to 76800
# getting from 76800 to 76850
# getting from 76850 to 76900
# getting from 76900 to 76950
# getting from 76950 to 77000
# getting from 77000 to 77050
# getting from 77050 to 77100
# getting from 77100 to 77150
# getting from 77150 to 77200
# getting from 77200 to 77250
# getting from 77250 to 77300
# getting from 77300 to 77350
# getting from 77350 to 77400
# getting from 77400 to 77450
# getting from 77450 to 77500
# getting from 77500 to 77550
# getting from 77550 to 77600
# getting from 77600 to 77650
# getting from 77650 to 77700
# getting from 77700 to 77750
# getting from 77750 to 77800
# getting from 77800 to 77850
# getting from 77850 to 77900
# getting from 77900 to 77950
# getting from 77950 to 78000
# getting from 78000 to 78050
# getting from 78050 to 78100
# getting from 78100 to 78150
# getting from 78150 to 78200
# getting from 78200 to 78250
# getting from 78250 to 78300
# getting from 78300 to 78350
# getting from 78350 to 78400
# getting from 78400 to 78450
# getting from 78450 to 78500
# getting from 78500 to 78550
# getting from 78550 to 78600
# getting from 78600 to 78650
# getting from 78650 to 78700
# getting from 78700 to 78750
# getting from 78750 to 78800
# getting from 78800 to 78850
# getting from 78850 to 78900
# getting from 78900 to 78950
# getting from 78950 to 79000
# getting from 79000 to 79050
# getting from 79050 to 79100
# getting from 79100 to 79150
# getting from 79150 to 79200
# getting from 79200 to 79250
# getting from 79250 to 79300
# getting from 79300 to 79350
# getting from 79350 to 79400
# getting from 79400 to 79450
# getting from 79450 to 79500
# getting from 79500 to 79550
# getting from 79550 to 79600
# getting from 79600 to 79650
# getting from 79650 to 79700
# getting from 79700 to 79750
# getting from 79750 to 79800
# getting from 79800 to 79850
# getting from 79850 to 79900
# getting from 79900 to 79950
# getting from 79950 to 80000
# getting from 80000 to 80050
# getting from 80050 to 80100
# getting from 80100 to 80150
# getting from 80150 to 80200
# getting from 80200 to 80250
# getting from 80250 to 80300
# getting from 80300 to 80350
# getting from 80350 to 80400
# getting from 80400 to 80450
# getting from 80450 to 80500
# getting from 80500 to 80550
# getting from 80550 to 80600
# getting from 80600 to 80650
# getting from 80650 to 80700
# getting from 80700 to 80750
# getting from 80750 to 80800
# getting from 80800 to 80850
# getting from 80850 to 80900
# getting from 80900 to 80950
# getting from 80950 to 81000
# getting from 81000 to 81050
# getting from 81050 to 81100
# getting from 81100 to 81150
# getting from 81150 to 81200
# getting from 81200 to 81250
# getting from 81250 to 81300
# getting from 81300 to 81350
# getting from 81350 to 81400
# getting from 81400 to 81450
# getting from 81450 to 81500
# getting from 81500 to 81550
# getting from 81550 to 81600
# getting from 81600 to 81650
# getting from 81650 to 81700
# getting from 81700 to 81750
# getting from 81750 to 81800
# getting from 81800 to 81850
# getting from 81850 to 81900
# getting from 81900 to 81950
# getting from 81950 to 82000
# getting from 82000 to 82050
# getting from 82050 to 82100
# getting from 82100 to 82150
# getting from 82150 to 82200
# getting from 82200 to 82250
# getting from 82250 to 82300
# getting from 82300 to 82350
# getting from 82350 to 82400
# getting from 82400 to 82450
# getting from 82450 to 82500
# getting from 82500 to 82550
# getting from 82550 to 82600
# getting from 82600 to 82650
# getting from 82650 to 82700
# getting from 82700 to 82750
# getting from 82750 to 82800
# getting from 82800 to 82850
# getting from 82850 to 82900
# getting from 82900 to 82950
# getting from 82950 to 83000
# getting from 83000 to 83050
# getting from 83050 to 83100
# getting from 83100 to 83150
# getting from 83150 to 83200
# getting from 83200 to 83250
# getting from 83250 to 83300
# getting from 83300 to 83350
# getting from 83350 to 83400
# getting from 83400 to 83450
# getting from 83450 to 83500
# getting from 83500 to 83550
# getting from 83550 to 83600
# getting from 83600 to 83650
# getting from 83650 to 83700
# getting from 83700 to 83750
# getting from 83750 to 83800
# getting from 83800 to 83850
# getting from 83850 to 83900
# getting from 83900 to 83950
# getting from 83950 to 84000
# getting from 84000 to 84050
# getting from 84050 to 84100
# getting from 84100 to 84150
# getting from 84150 to 84200
# getting from 84200 to 84250
# getting from 84250 to 84300
# getting from 84300 to 84350
# getting from 84350 to 84400
# getting from 84400 to 84450
# getting from 84450 to 84500
# getting from 84500 to 84550
# getting from 84550 to 84600
# getting from 84600 to 84650
# getting from 84650 to 84700
# getting from 84700 to 84750
# getting from 84750 to 84800
# getting from 84800 to 84850
# getting from 84850 to 84900
# getting from 84900 to 84950
# getting from 84950 to 85000
# getting from 85000 to 85050
# getting from 85050 to 85100
# getting from 85100 to 85150
# getting from 85150 to 85200
# getting from 85200 to 85250
# getting from 85250 to 85300
# getting from 85300 to 85350
# getting from 85350 to 85400
# getting from 85400 to 85450
# getting from 85450 to 85500
# getting from 85500 to 85550
# getting from 85550 to 85600
# getting from 85600 to 85650
# getting from 85650 to 85700
# getting from 85700 to 85750
# getting from 85750 to 85800
# getting from 85800 to 85850
# getting from 85850 to 85900
# getting from 85900 to 85950
# getting from 85950 to 86000
# getting from 86000 to 86050
# getting from 86050 to 86100
# getting from 86100 to 86150
# getting from 86150 to 86200
# getting from 86200 to 86250
# getting from 86250 to 86300
# getting from 86300 to 86350
# getting from 86350 to 86400
# getting from 86400 to 86450
# getting from 86450 to 86500
# ...
# getting from 106300 to 106350
# getting from 106350 to 106400
# getting from 106400 to 106450
# getting from 106450 to 106500
# getting from 106500 to 106550
# getting from 106550 to 106600
# getting from 106600 to 106650
# getting from 106650 to 106700
# getting from 106700 to 106750
# getting from 106750 to 106800
# getting from 106800 to 106850
# getting from 106850 to 106900
# getting from 106900 to 106950
# getting from 106950 to 107000
# getting from 107000 to 107050
# getting from 107050 to 107100
# getting from 107100 to 107150
# getting from 107150 to 107200
# getting from 107200 to 107250
# getting from 107250 to 107300
# getting from 107300 to 107350
# getting from 107350 to 107400
# getting from 107400 to 107450
# getting from 107450 to 107500
# getting from 107500 to 107550
# getting from 107550 to 107600
# getting from 107600 to 107650
# getting from 107650 to 107700
# getting from 107700 to 107750
# getting from 107750 to 107800
# getting from 107800 to 107850
# getting from 107850 to 107900
# getting from 107900 to 107950
# getting from 107950 to 108000
# getting from 108000 to 108050
# getting from 108050 to 108100
# getting from 108100 to 108150
# getting from 108150 to 108200
# getting from 108200 to 108250
# getting from 108250 to 108300
# getting from 108300 to 108350
# getting from 108350 to 108400
# getting from 108400 to 108450
# getting from 108450 to 108500
# getting from 108500 to 108550
# getting from 108550 to 108600
# getting from 108600 to 108650
# getting from 108650 to 108700
# getting from 108700 to 108750
# getting from 108750 to 108800
# getting from 108800 to 108850
# getting from 108850 to 108900
# getting from 108900 to 108950
# getting from 108950 to 109000
# getting from 109000 to 109050
# getting from 109050 to 109100
# getting from 109100 to 109150
# getting from 109150 to 109200
# getting from 109200 to 109250
# getting from 109250 to 109300
# getting from 109300 to 109350
# getting from 109350 to 109400
# getting from 109400 to 109450
# getting from 109450 to 109500
# getting from 109500 to 109550
# getting from 109550 to 109600
# getting from 127350 to 127400
# getting from 127400 to 127450
# getting from 127450 to 127500
# getting from 127500 to 127550
# getting from 127550 to 127600
# getting from 127600 to 127650
# getting from 127650 to 127700
# getting from 127700 to 127750
# getting from 127750 to 127800
# getting from 127800 to 127850
# getting from 127850 to 127900
# getting from 127900 to 127950
# getting from 127950 to 128000
# getting from 128000 to 128050
# getting from 128050 to 128100
# getting from 128100 to 128150
# getting from 128150 to 128200
# getting from 128200 to 128250
# getting from 128250 to 128300
# getting from 128300 to 128350
# getting from 128350 to 128400
# getting from 128400 to 128450
# getting from 128450 to 128500
# getting from 128500 to 128550
# getting from 128550 to 128600
# getting from 128600 to 128650
# getting from 128650 to 128700
# getting from 128700 to 128750
# getting from 128750 to 128800
# getting from 128800 to 128850
# getting from 128850 to 128900
# getting from 128900 to 128950
# getting from 128950 to 129000
# getting from 129000 to 129050
# getting from 129050 to 129100
# getting from 129100 to 129150
# getting from 129150 to 129200
# getting from 129200 to 129250
# getting from 129250 to 129300
# getting from 129300 to 129350
# getting from 129350 to 129400
# getting from 129400 to 129450
# getting from 129450 to 129500
# getting from 129500 to 129550
# getting from 129550 to 129600
# getting from 129600 to 129650
# getting from 129650 to 129700
# getting from 129700 to 129750
# getting from 129750 to 129800
# getting from 129800 to 129850
# getting from 129850 to 129900
# getting from 129900 to 129950
# getting from 129950 to 130000
# getting from 130000 to 130050
# getting from 130050 to 130100
# getting from 130100 to 130150
# getting from 130150 to 130200
# getting from 130200 to 130250
# getting from 130250 to 130300
# getting from 130300 to 130350
# getting from 130350 to 130400
# getting from 130400 to 130450
# getting from 130450 to 130500
# getting from 130500 to 130550
# getting from 130550 to 130600
# getting from 130600 to 130650
# getting from 130650 to 130700
# getting from 130700 to 130750
# getting from 130750 to 130800
# getting from 130800 to 130850
# getting from 130850 to 130900
# getting from 130900 to 130950
# getting from 130950 to 131000
# getting from 131000 to 131050
# getting from 131050 to 131100
# getting from 131100 to 131150
# getting from 131150 to 131200
# getting from 131200 to 131250
# getting from 131250 to 131300
# getting from 131300 to 131350
# getting from 131350 to 131400
# getting from 131400 to 131450
# getting from 131450 to 131500
# getting from 131500 to 131550
# getting from 131550 to 131600
# getting from 131600 to 131650
# getting from 131650 to 131700
# getting from 131700 to 131750
# getting from 131750 to 131800
# getting from 131800 to 131850
# getting from 131850 to 131900
# getting from 131900 to 131950
# getting from 131950 to 132000
# getting from 132000 to 132050
# getting from 132050 to 132100
# getting from 132100 to 132150
# getting from 132150 to 132200
# getting from 132200 to 132250
# getting from 132250 to 132300
# getting from 132300 to 132350
# getting from 132350 to 132400
# getting from 132400 to 132450
# getting from 132450 to 132500
# getting from 132500 to 132550
# getting from 132550 to 132600
# getting from 132600 to 132650
# getting from 132650 to 132700
# getting from 132700 to 132750
# getting from 132750 to 132800
# getting from 132800 to 132850
# getting from 132850 to 132900
# getting from 132900 to 132950

# %% [markdown]
# * We check that we fetched the features for all the songs successfully.

# %%
print(len(audio_features), len(track_features))
# Out:
# 132940 132940

# %% [markdown]
# * We also check for None results from the API.
# * First, we check for the high level audio features and delete if necessary.

# %%
test_audio_features = audio_features.copy()

# %%
for index, s in test_audio_features.items():
    if test_audio_features[index] is None:
        del audio_features[index]

# %% [markdown]
# * We create the DataFrame with the high level audio feautres data.
# * We keep only the columns that might be useful for our task.
# * The selected columns are:
#     1. **acousticness**: How much acoustic is the track.
#     2. **danceability**: How suitable is the track for dancing.
#     3. **duration_ms**: The duration of the track in ms.
#     4. **energy**: A perceptual measure of the intensity and the activity, expressed by the track.
#     5. **instrumentalness** : The likelihood that the track contains no vocals and only instruments.
#     6. **key**: The key that the track is in. There are 12 integers that map to pitches using the [Pitch class notation](https://en.wikipedia.org/wiki/Pitch_class).
#     7. **liveliness**: The probability that the track was performes live.
#     8. **loudness**: The overall loudness of a track in decibels (dB).
#     9. **mode**: The modality of the track (major or minor).
#     10. **speechiness**: The volume of spoken words in the track.
#     11. **tempo**: The overall estimated tempo of the track in beats per minute (BPM).
#     12. **time_signature**: How many beats are in each bar of the track.
#     13. **valence**: A measure describing the musical positiveness conveyed by the track *(our target value)*.
#
# *More information about the attributes [here](https://developer.spotify.com/documentation/web-api/reference/#/operations/get-several-audio-features).*

# %%
tracks = pd.DataFrame.from_dict(audio_features, orient='index')
tracks.drop(columns=['type', 'id', 'uri', 'track_href', 'analysis_url'], inplace=True)
tracks
# Out:
#                         danceability  energy  key  loudness  mode  \
# 4a2qoYY6xINDXtUOBFbJ6d         0.122  0.0182    2   -27.890     1
# 238ByVSDcz260ewWOEgAQf         0.415  0.1320    0   -17.186     1
# 533Q9BiC93uzp3AnvMNLmc         0.769  0.4360    7    -5.716     1
# 3DytidwwDXv5gZVilj2lO1         0.559  0.7200    0    -5.948     1
# 1Xkpw8X6WVmkditTPZ7YSk         0.481  0.3870    2   -16.633     1
# ...                              ...     ...  ...       ...   ...
# 4K87CebUVshxBCfwv4Gjs8         0.704  0.2350    9   -17.272     1
# 36PNa2n55qLfQd7KLXyeoy         0.723  0.7240    0    -6.378     1
# 0ukMJRQa8UoAbtNVIhEgYE         0.543  0.5640    2   -10.260     1
# 2iguaRelnM3P06EOcBjsv9         0.497  0.6540    0    -9.714     1
# 6M33HiUHLC3R3gfXYNGMAy         0.955  0.7680    1    -5.540     0
#
#                         speechiness  acousticness  instrumentalness  liveness  \
# 4a2qoYY6xINDXtUOBFbJ6d       0.0383      0.967000          0.834000    0.0735
# 238ByVSDcz260ewWOEgAQf       0.0436      0.981000          0.179000    0.1650
# 533Q9BiC93uzp3AnvMNLmc       0.0505      0.715000          0.000000    0.1700
# 3DytidwwDXv5gZVilj2lO1       0.0302      0.111000          0.000105    0.3280
# 1Xkpw8X6WVmkditTPZ7YSk       0.0416      0.901000          0.820000    0.1560
# ...                             ...           ...               ...       ...
# 4K87CebUVshxBCfwv4Gjs8       0.9530      0.750000          0.000000    0.3700
# 36PNa2n55qLfQd7KLXyeoy       0.0304      0.294000          0.000000    0.1210
# 0ukMJRQa8UoAbtNVIhEgYE       0.0404      0.047100          0.000000    0.0936
# 2iguaRelnM3P06EOcBjsv9       0.0296      0.000507          0.390000    0.2030
# 6M33HiUHLC3R3gfXYNGMAy       0.1810      0.013400          0.000000    0.3080
#
#                         valence    tempo  duration_ms  time_signature
# 4a2qoYY6xINDXtUOBFbJ6d   0.0473   77.590       477733               3
# 238ByVSDcz260ewWOEgAQf   0.4180   92.253       200040               4
# 533Q9BiC93uzp3AnvMNLmc   0.9710  119.675       297494               3
# 3DytidwwDXv5gZVilj2lO1   0.6830  125.139       228133               4
# 1Xkpw8X6WVmkditTPZ7YSk   0.7400  110.564       112039               4
# ...                         ...      ...          ...             ...
# 4K87CebUVshxBCfwv4Gjs8   0.4010  131.762       329497               4
# 36PNa2n55qLfQd7KLXyeoy   0.9270  117.990       251787               4
# 0ukMJRQa8UoAbtNVIhEgYE   0.8460   92.839       103173               4
# 2iguaRelnM3P06EOcBjsv9   0.8300  144.099       125453               3
# 6M33HiUHLC3R3gfXYNGMAy   0.7410  125.040       194293               4
#
# [132940 rows x 13 columns]

# %% [markdown]
# * We follow the same procedure for the track features.

# %%
test_track_features = track_features.copy()

# %%
for index, s in test_track_features.items():
    if test_track_features[index] is None:
        del track_features[index]

# %% [markdown]
# * Again we do not keep all the columns, but only those that might be useful for our task.
# * The selected columns are:
#     1. **explicit**: Whether or not the track has explicit lyrics (transformed to binary (0,1)).
#     2. **year**: The year that the track was released (created from the *release_date*).
#
# *More information about the attributes [here](https://developer.spotify.com/documentation/web-api/reference/#/operations/get-track).*

# %%
extra_features = pd.DataFrame.from_dict(track_features, orient='index')
extra_features['explicit'] = np.where(extra_features['explicit'] == True, 1, 0)
extra_features['year'] = extra_features['release_date'].apply(lambda x: int(x[0:4]))
extra_features.drop(columns='release_date', inplace=True)
extra_features
# Out:
#                         explicit  year
# 4a2qoYY6xINDXtUOBFbJ6d         0  1985
# 238ByVSDcz260ewWOEgAQf         0  1949
# 533Q9BiC93uzp3AnvMNLmc         0  2004
# 3DytidwwDXv5gZVilj2lO1         0  1979
# 1Xkpw8X6WVmkditTPZ7YSk         0  1959
# ...                          ...   ...
# 4K87CebUVshxBCfwv4Gjs8         0  1935
# 36PNa2n55qLfQd7KLXyeoy         0  2008
# 0ukMJRQa8UoAbtNVIhEgYE         0  1968
# 2iguaRelnM3P06EOcBjsv9         0  1947
# 6M33HiUHLC3R3gfXYNGMAy         1  2000
#
# [132940 rows x 2 columns]

# %% [markdown]
# * We merge the two DataFrames to acquire the complete DataFrame for the track and high level audio features.

# %%
tracks = tracks.merge(extra_features, left_index=True, right_index=True, how='inner')
tracks
# Out:
#                         danceability  energy  key  loudness  mode  \
# 4a2qoYY6xINDXtUOBFbJ6d         0.122  0.0182    2   -27.890     1
# 238ByVSDcz260ewWOEgAQf         0.415  0.1320    0   -17.186     1
# 533Q9BiC93uzp3AnvMNLmc         0.769  0.4360    7    -5.716     1
# 3DytidwwDXv5gZVilj2lO1         0.559  0.7200    0    -5.948     1
# 1Xkpw8X6WVmkditTPZ7YSk         0.481  0.3870    2   -16.633     1
# ...                              ...     ...  ...       ...   ...
# 4K87CebUVshxBCfwv4Gjs8         0.704  0.2350    9   -17.272     1
# 36PNa2n55qLfQd7KLXyeoy         0.723  0.7240    0    -6.378     1
# 0ukMJRQa8UoAbtNVIhEgYE         0.543  0.5640    2   -10.260     1
# 2iguaRelnM3P06EOcBjsv9         0.497  0.6540    0    -9.714     1
# 6M33HiUHLC3R3gfXYNGMAy         0.955  0.7680    1    -5.540     0
#
#                         speechiness  acousticness  instrumentalness  liveness  \
# 4a2qoYY6xINDXtUOBFbJ6d       0.0383      0.967000          0.834000    0.0735
# 238ByVSDcz260ewWOEgAQf       0.0436      0.981000          0.179000    0.1650
# 533Q9BiC93uzp3AnvMNLmc       0.0505      0.715000          0.000000    0.1700
# 3DytidwwDXv5gZVilj2lO1       0.0302      0.111000          0.000105    0.3280
# 1Xkpw8X6WVmkditTPZ7YSk       0.0416      0.901000          0.820000    0.1560
# ...                             ...           ...               ...       ...
# 4K87CebUVshxBCfwv4Gjs8       0.9530      0.750000          0.000000    0.3700
# 36PNa2n55qLfQd7KLXyeoy       0.0304      0.294000          0.000000    0.1210
# 0ukMJRQa8UoAbtNVIhEgYE       0.0404      0.047100          0.000000    0.0936
# 2iguaRelnM3P06EOcBjsv9       0.0296      0.000507          0.390000    0.2030
# 6M33HiUHLC3R3gfXYNGMAy       0.1810      0.013400          0.000000    0.3080
#
#                         valence    tempo  duration_ms  time_signature  \
# 4a2qoYY6xINDXtUOBFbJ6d   0.0473   77.590       477733               3
# 238ByVSDcz260ewWOEgAQf   0.4180   92.253       200040               4
# 533Q9BiC93uzp3AnvMNLmc   0.9710  119.675       297494               3
# 3DytidwwDXv5gZVilj2lO1   0.6830  125.139       228133               4
# 1Xkpw8X6WVmkditTPZ7YSk   0.7400  110.564       112039               4
# ...                         ...      ...          ...             ...
# 4K87CebUVshxBCfwv4Gjs8   0.4010  131.762       329497               4
# 36PNa2n55qLfQd7KLXyeoy   0.9270  117.990       251787               4
# 0ukMJRQa8UoAbtNVIhEgYE   0.8460   92.839       103173               4
# 2iguaRelnM3P06EOcBjsv9   0.8300  144.099       125453               3
# 6M33HiUHLC3R3gfXYNGMAy   0.7410  125.040       194293               4
#
#                         explicit  year
# 4a2qoYY6xINDXtUOBFbJ6d         0  1985
# 238ByVSDcz260ewWOEgAQf         0  1949
# 533Q9BiC93uzp3AnvMNLmc         0  2004
# 3DytidwwDXv5gZVilj2lO1         0  1979
# 1Xkpw8X6WVmkditTPZ7YSk         0  1959
# ...                          ...   ...
# 4K87CebUVshxBCfwv4Gjs8         0  1935
# 36PNa2n55qLfQd7KLXyeoy         0  2008
# 0ukMJRQa8UoAbtNVIhEgYE         0  1968
# 2iguaRelnM3P06EOcBjsv9         0  1947
# 6M33HiUHLC3R3gfXYNGMAy         1  2000
#
# [132940 rows x 15 columns]

# %% [markdown]
# * We also make some checks to ensure that there are no NaN values and that all the ids are unique.

# %%
tracks.isna().sum()
# Out:
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# duration_ms         0
# time_signature      0
# explicit            0
# year                0
# dtype: int64

# %%
len(tracks.index.unique()) == len(tracks)
# Out:
# True

# %% [markdown]
# * Lastly, because the predicting models will be evaluated by specific track set, we discard all the tracks that exist in the final evaluation set.

# %%
test_ids = [line.strip() for line in open('data/spotify_ids.txt')]
len(test_ids)
# Out:
# 1162

# %%
excluded_ids = tracks.index.isin(test_ids)
tracks = tracks.loc[~excluded_ids]
tracks
# Out:
#                         danceability  energy  key  loudness  mode  \
# 4a2qoYY6xINDXtUOBFbJ6d         0.122  0.0182    2   -27.890     1
# 238ByVSDcz260ewWOEgAQf         0.415  0.1320    0   -17.186     1
# 533Q9BiC93uzp3AnvMNLmc         0.769  0.4360    7    -5.716     1
# 3DytidwwDXv5gZVilj2lO1         0.559  0.7200    0    -5.948     1
# 1Xkpw8X6WVmkditTPZ7YSk         0.481  0.3870    2   -16.633     1
# ...                              ...     ...  ...       ...   ...
# 4K87CebUVshxBCfwv4Gjs8         
# %% [markdown]
# * We can see now that there no common ids.

# %%
# Code obtained from Stack Overflow, https://stackoverflow.com/questions/2864842/common-elements-comparison-between-2-lists
list(set(test_ids).intersection(list(tracks.index)))
# Out:
# []

# %% [markdown]
# * We export the data to a csv file.

# %%
tracks.to_csv('data/tracks.csv')

# %% [markdown]
# ### Low Level Audio Features

# %% [markdown]
# * To enrich our data we will use some low level audio features that provide more detailed information about the tracks.
# * Specifically we will concetrate to the segments of a track.
# * Each segment contains a roughly conisistent sound throughout its duration.

# %% [markdown]
# * From the segments we will obtain three attributes:
#     1. **Pitches**: Pitches provide a "chroma" vector that describes the dominance of every pitch (12 in total) in the chromatic scale.
#     2. **Timbre**: Timbre is the quality of a musical note or sound that distinguishes different types of musical instruments, or voices. It is also reffered as sound color. Timbre provided by Spotify's API is the result of a PCA and it's presented by a 12 value vector.
#     3. **Loudness Attributes**: The loudness attributes are, *loudness_start*, which indicates the onset loudness of the segment, *loudness_max*, which indicates the peak loudness of the segment and *loudness_max_time* which indicates the the segment-relative offset of the segment peak loudness in seconds. All together describe the "attack" of the song.
#
#     *More information about the attributes [here](https://developer.spotify.com/documentation/web-api/reference/#/operations/get-audio-analysis).*

# %% [markdown]
# * To facilitate the data exctraction we create three functions.

# %% [markdown]
# * The first function returns a 2D numpy array with the pitches of every segment.

# %%
def get_pitch(segments):
    pitch_a = np.empty((0,12), int)
    for i in segments:
        pitch_a = np.append(pitch_a, np.array([i['pitches']]), axis=0)
    return pitch_a

# %% [markdown]
# * The second function returns a 2D numpy array with the timbre of every segment.

# %%
def get_timbre(segments):
    timbre_a = np.empty((0,12), int)
    for i in segments:
        timbre_a = np.append(timbre_a, np.array([i['timbre']]), axis=0)
    return timbre_a

# %% [markdown]
# * The last function returns a 2D numpy array with the loudness attributes of every segment.

# %%
def get_loudness(segments):
    loudness_a = np.empty((0,3), int)
    for i in segments:
        l = [i['loudness_start'], i['loudness_max_time'], i['loudness_max']]
        loudness_a = np.append(loudness_a, np.array([l]), axis=0)
    return loudness_a

# %% [markdown]
# * Also, we create the function that performs the requests.
# * The function uses the `sp.audio_analysis` method to acquire the data.
# * Because this endpoint does not provide batch requests, we will acquire the audio analysis for one track per request.
# * The function returns three dictionaries with the previously mentioned 2D arrays, for each track.

# %%
def get_audio_analysis(track_ids, limit):    
    state = 0
    audio_analysis_pitch = {}
    audio_analysis_timbre = {}
    audio_analysis_loudness = {}

    while len(audio_analysis_pitch) < limit:

        try:
            track = track_ids[state]

            track_analysis = sp.audio_analysis(track)
            pitches = get_pitch(track_analysis['segments'])
            timbre = get_timbre(track_analysis['segments'])
            loudness = get_loudness(track_analysis['segments'])

            audio_analysis_pitch.update({ track : pitches})
            audio_analysis_timbre.update({ track : timbre})
            audio_analysis_loudness.update({ track : loudness})

        except Exception:
            print('error:', state)

        state += 1
    
    return audio_analysis_pitch, audio_analysis_timbre, audio_analysis_loudness

# %% [markdown]
# * Due to lack of resources we will obtain the data for 60,000 tracks (~5 hours).
#
# *(Depending on your RAM you may need to obtain less tracks or obtain them in batches. This was performed by using 16 GB)*

# %%
audio_analysis_pitch, audio_analysis_timbre, audio_analysis_loudness = get_audio_analysis(all_track_ids, 60000)

# %% [markdown]
# * We remove all the tracks that exist in the final evaluation set.

# %%
collected_ids = list(audio_analysis_pitch.keys())

for track_id in collected_ids:
    if track_id in test_ids:
        del audio_analysis_pitch[track_id]
        del audio_analysis_timbre[track_id]
        del audio_analysis_loudness[track_id]

# %%
print(len(audio_analysis_pitch), len(audio_analysis_timbre), len(audio_analysis_loudness))
# Out:
# 59960 59960 59960

# %% [markdown]
# * In the analysis notebook the pitches and the timbre will be tranformed and used as input in the Convolutional Neural Network.
# * To save them and use as less space as possible we keep only the 150 first segments.
# * First, we check for the tracks that have 150 and over segments.

# %%
accept_list = []

for track_id, a in audio_analysis_pitch.items():
    dim = a.shape[0]
    if (dim >= 150):
        accept_list.append(track_id)
        
len(accept_list)
# Out:
# 59559

# %% [markdown]
# * Then we perform the downsizing on these tracks.

# %%
for i in accept_list:
    audio_analysis_timbre[i] = audio_analysis_timbre[i][0:150,]
    audio_analysis_pitch[i] = audio_analysis_pitch[i][0:150,]

# %% [markdown]
# * We save the results in .npy files.
# * In this way we can load the data and make further transormations at any time.

# %%
np.save('data/pitch.npy',audio_analysis_pitch)
np.save('data/timbre.npy',audio_analysis_timbre)

# %% [markdown]
# * We will not only use the raw pitches and timbre.
# * For each of the three attributes (pitches, timbre, loudness attributes) we find the mean values, from all the segments of a track.
# * As a result we get:
#     1. For the *pitches*, a 12 value vector with the mean value of each element.
#     2. For the *timbre*, a 12 value vector with the mean of each element.
#     3. For the *loudness attributes*, a 3 value vector with the mean of each attribute.

# %%
audio_analysis_pitch_mean = {}
for track_id, analysis in audio_analysis_pitch.items():
    pitch_mean = np.mean(analysis, axis=0)
    audio_analysis_pitch_mean.update({ track_id : pitch_mean})

# %%
audio_analysis_timbre_mean = {}
for track_id, analysis in audio_analysis_timbre.items():
    timbre_mean = np.mean(analysis, axis=0)
    audio_analysis_timbre_mean.update({ track_id : timbre_mean})

# %%
audio_analysis_loudness_mean = {}
for track_id, analysis in audio_analysis_loudness.items():
    loudness_mean = np.mean(analysis, axis=0)
    audio_analysis_loudness_mean.update({ track_id : loudness_mean})

# %% [markdown]
# * Next, we transform the 3 vectors with the mean values to DataFrames.

# %%
pitch_analysis = pd.DataFrame.from_dict(audio_analysis_pitch_mean, orient='index')
pitch_analysis = pitch_analysis.add_prefix('pitch_')
pitch_analysis
# Out:
#                          pitch_0   pitch_1   pitch_2   pitch_3   pitch_4  \
# 238ByVSDcz260ewWOEgAQf  0.460020  0.201881  0.240555  0.169500  0.334406
# 533Q9BiC93uzp3AnvMNLmc  0.360192  0.385989  0.551523  0.210450  0.270202
# 3DytidwwDXv5gZVilj2lO1  0.846527  0.426190  0.288279  0.187522  0.303811
# 1Xkpw8X6WVmkditTPZ7YSk  0.259775  0.444462  0.419316  0.237481  0.421523
# 49C6EGQhCUSgyADHYvJ7ez  0.348984  0.402577  0.329118  0.272448  0.513416
# ...                          ...       ...       ...       ...       ...
# 5XgCk8ikjfTx02rgxNULEy  0.179790  0.424339  0.463222  0.172609  0.244581
# 5K99RGHiLcXAEgrPvw5x8B  0.283515  0.459829  0.238144  0.115733  0.212125
# 1Um0R2yaEzp6EmfUhmWkzc  0.371257  0.360626  0.358172  0.328551  0.216945
# 1p3vijWl4pezgUtyCmCVln  0.399122  0.421652  0.236681  0.374762  0.200595
# 1ZAO69cQCML5s47SAca93d  0.436568  0.361017  0.293913  0.271132  0.251325
#
#                          pitch_5   pitch_6   pitch_7   pitch_8   pitch_9
# 1Um0R2yaEzp6EmfUhmWkzc      -21.376024           0.084418    -14.154549
# 1p3vijWl4pezgUtyCmCVln      -19.955407           0.072397    -11.868696
# 1ZAO69cQCML5s47SAca93d      -28.213477           0.086787    -18.662558
#
# [59960 rows x 3 columns]

# %% [markdown]
# * We merge all the DataFrames with the low level audio features.

# %%
audio_analysis = pitch_analysis.merge(timbre_analysis.merge(loudness_analysis, left_index=True, right_index=True, how='inner'), left_index=True, right_index=True, how='inner')
audio_analysis
# Out:
#                          pitch_0   pitch_1   pitch_2   pitch_3   pitch_4  \
# 238ByVSDcz260ewWOEgAQf  0.460020  0.201881  0.240555  0.169500  0.334406
# 533Q9BiC93uzp3AnvMNLmc  0.360192  0.385989  0.551523  0.210450  0.270202
# 3DytidwwDXv5gZVilj2lO1  0.846527  0.426190  0.288279  0.187522  0.303811
# 1Xkpw8X6WVmkditTPZ7YSk  0.259775  0.444462  0.419316  0.237481  0.421523
# 49C6EGQhCUSgyADHYvJ7ez  0.348984  0.402577  0.329118  0.272448  0.513416
# ...                          ...       ...       ...       ...       ...
# 5XgCk8ikjfTx02rgxNULEy  0.179790  0.424339  0.463222  0.172609  0.244581
# 5K99RGHiLcXAEgrPvw5x8B  0.283515  0.459829  0.238144  0.115733  0.212125
# 1Um0R2yaEzp6EmfUhmWkzc  0.371257  0.360626  0.358172  0.328551  0.216945
# 1p3vijWl4pezgUtyCmCVln  0.399122  0.421652  0.236681  0.374762  0.200595
# 1ZAO69cQCML5s47SAca93d  0.436568  0.361017  0.293913  0.271132  0.251325
#
#                          pitch_5   pitch_6   pitch_7   pitch_8   pitch_9  ...  \
# 238ByVSDcz260ewWOEgAQf  0.346195  0.259822  0.380519  0.182167  0.226228  ...
# 533Q9BiC93uzp3AnvMNLmc  0.172840  0.367805  0.393697  0.203855  0.374937  ...
# 3DytidwwDXv5gZVilj2lO1  0.432586  0.225100  0.355768  0.215971  0.292785  ...
# 1Xkpw8X6WVmkditTPZ7YSk  0.316850  0.162951  0.329795  0.294014  0.365389  ...
# 49C6EGQhCUSgyADHYvJ7ez  0.340941  0.331070  0.469664  0.486889  0.565561  ...
# ...                          ...       ...       ...       ...       ...  ...
# 5XgCk8ikjfTx02rgxNULEy  0.182408  0.344043  0.235784  0.211337  0.425495  ...
# 5K99RGHiLcXAEgrPvw5x8B  0.548562  0.185078  0.187220  0.262938  0.482391  ...
# 1Um0R2yaEzp6EmfUhmWkzc  0.205512  0.229466  0.449279  0.393903  0.255304  ...
# 1p3vijWl4pezgUtyCmCVln  0.232562  0.289443  0.191954  0.392973  0.296376  ...
# 1ZAO69cQCML5s47SAca93d  0.305283  0.200392  0.240235  0.275943  0.337315  ...
#
#                          timbre_5   timbre_6   timbre_7   timbre_8   timbre_9  \
# 238ByVSDcz260ewWOEgAQf -16.627843 -13.930937   0.223931  -6.450813  -5.146013
# 533Q9BiC93uzp3AnvMNLmc  -4.948037 -20.320301   8.109223   3.246466   2.691535
# 3DytidwwDXv5gZVilj2lO1 -20.668999   7.369926   6.275858   0.816352  -0.849888
# 1Xkpw8X6WVmkditTPZ7YSk -28.811045  26.761367   3.937700  -0.728032  11.823055
# 49C6EGQhCUSgyADHYvJ7ez -20.445113   4.539008  13.935807  -9.770754  -3.445520
# ...                           ...        ...        ...        ...        ...
# 5XgCk8ikjfTx02rgxNULEy -21.037345 -16.483287  -2.807175   1.498037   0.754020
# 5K99RGHiLcXAEgrPvw5x8B -22.826544 -13.960940  -5.026567 -11.716491  -6.564302
# 1Um0R2yaEzp6EmfUhmWkzc -17.311905 -28.104022  -3.548257  21.026206   6.822775
# 1p3vijWl4pezgUtyCmCVln -22.838964   8.894932  -0.502899  -5.193930  -8.395782
# 1ZAO69cQCML5s47SAca93d   2.670229 -19.767697   3.581049  -5.141698  -2.640052
#
#                         timbre_10  timbre_11  loudness_start  \
# 238ByVSDcz260ewWOEgAQf  -6.132500   4.896064      -26.655862
# 533Q9BiC93uzp3AnvMNLmc -12.141557  -1.579897      -16.976020
# 3DytidwwDXv5gZVilj2lO1  -7.378406   0.654819      -13.735490
# 1Xkpw8X6WVmkditTPZ7YSk -16.817598   2.946972      -26.885414
# 49C6EGQhCUSgyADHYvJ7ez  -9.008125 -12.408444      -15.827730
# ...                           ...        ...             ...
# 5XgCk8ikjfTx02rgxNULEy  -6.064358   2.763354      -22.969223
# 5K99RGHiLcXAEgrPvw5x8B  -3.742398  10.847945      -22.160860
# 1Um0R2yaEzp6EmfUhmWkzc  -6.141358  11.447684      -21.376024
# 1p3vijWl4pezgUtyCmCVln  -8.869433  -0.952230      -19.955407
# 1ZAO69cQCML5s47SAca93d -10.385931   3.953759      -28.213477
#
#                         loudness_max_time  loudness_max
# 238ByVSDcz260ewWOEgAQf           0.083081    -19.040579
# 533Q9BiC93uzp3AnvMNLmc           0.063622     -5.893591
# 3DytidwwDXv5gZVilj2lO1           0.063940     -6.919745
# 1Xkpw8X6WVmkditTPZ7YSk           0.042667    -17.600172
# 49C6EGQhCUSgyADHYvJ7ez           0.059064     -8.513015
# ...                                   ...           ...
# 5XgCk8ikjfTx02rgxNULEy           0.085119    -17.191883
# 5K99RGHiLcXAEgrPvw5x8B           0.079966    -17.219731
# 1Um0R2yaEzp6EmfUhmWkzc           0.084418    -14.154549
# 1p3vijWl4pezgUtyCmCVln           0.072397    -11.868696
# 1ZAO69cQCML5s47SAca93d           0.086787    -18.662558
#
# [59960 rows x 27 columns]

# %% [markdown]
# * Lastly, we merge the DataFrame that contains the high level audio and track features with the DataFrame that contains the low level audio features.

# %%
low_level_tracks = audio_analysis.merge(tracks, left_index=True, right_index=True, how='inner')
low_level_tracks
# Out:
#                          pitch_0   pitch_1   pitch_2   pitch_3   pitch_4  \
# 238ByVSDcz260ewWOEgAQf  0.460020  0.201881  0.240555  0.169500  0.334406
# 533Q9BiC93uzp3AnvMNLmc  0.360192  0.385989  0.551523  0.210450  0.270202
# 3DytidwwDXv5gZVilj2lO1  0.846527  0.426190  0.288279  0.187522  0.303811
# 1Xkpw8X6WVmkditTPZ7YSk  0.259775  0.444462  0.419316  0.237481  0.421523
# 49C6EGQhCUSgyADHYvJ7ez  0.348984  0.402577  0.329118  0.272448  0.513416
# ...                          ...       ...       ...       ...       ...
# 5XgCk8ikjfTx02rgxNULEy  0.179790  0.424339  0.463222  0.172609  0.244581
# 1p3vijWl4pezgUtyCmCVln   0.2540  139.886       418507               4
# 1ZAO69cQCML5s47SAca93d   0.1240  105.513       168147               3
#
#                         explicit  year
# 238ByVSDcz260ewWOEgAQf         0  1949
# 533Q9BiC93uzp3AnvMNLmc         0  2004
# 3DytidwwDXv5gZVilj2lO1         0  1979
# 1Xkpw8X6WVmkditTPZ7YSk         0  1959
# 49C6EGQhCUSgyADHYvJ7ez         0  1969
# ...                          ...   ...
# 5XgCk8ikjfTx02rgxNULEy         0  1997
# 5K99RGHiLcXAEgrPvw5x8B         0  1973
# 1Um0R2yaEzp6EmfUhmWkzc         0  1944
# 1p3vijWl4pezgUtyCmCVln         1  2012
# 1ZAO69cQCML5s47SAca93d         0  1951
#
# [59960 rows x 42 columns]

# %% [markdown]
# * Before exporting the data we make some checks to ensure that there are no NaN values and that all the ids are unique.

# %%
low_level_tracks.isna().sum()
# Out:
# pitch_0              0
# pitch_1              0
# pitch_2              0
# pitch_3              0
# pitch_4              0
# pitch_5              0
# pitch_6              0
# pitch_7              0
# pitch_8              0
# pitch_9              0
# pitch_10             0
# pitch_11             0
# timbre_0             0
# timbre_1             0
# timbre_2             0
# timbre_3             0
# timbre_4             0
# timbre_5             0
# timbre_6             0
# timbre_7             0
# timbre_8             0
# timbre_9             0
# timbre_10            0
# timbre_11            0
# loudness_start       0
# loudness_max_time    0
# loudness_max         0
# danceability         0
# energy               0
# key                  0
# loudness             0
# mode                 0
# speechiness          0
# acousticness         0
# instrumentalness     0
# liveness             0
# valence              0
# tempo                0
# duration_ms          0
# time_signature       0
# explicit             0
# year                 0
# dtype: int64

# %%
len(low_level_tracks.index.unique()) == len(low_level_tracks)
# Out:
# True

# %% [markdown]
# * We export the data to a csv file.

# %%
low_level_tracks.to_csv('data/low_level_tracks.csv')

# %% [markdown]
# ### Final Evaluation Data

# %% [markdown]
# The prediction models will be evaluated by a final data set. As a result we have to follow the same procedure to obtain the evaluation data.

# %% [markdown]
# * First, we acquire the high level audio features.

# %%
audio_features_eval = get_audio_features(test_ids)
# Out:
# getting from 0 to 100
# getting from 100 to 200
# getting from 200 to 300
# getting from 300 to 400
# getting from 400 to 500
# getting from 500 to 600
# getting from 600 to 700
# getting from 700 to 800
# getting from 800 to 900
# getting from 900 to 1000
# getting from 1000 to 1100
# getting from 1100 to 1200

# %%
tracks_eval = pd.DataFrame.from_dict(audio_features_eval, orient='index')
tracks_eval.drop(columns=['type', 'id', 'uri', 'track_href', 'analysis_url'], inplace=True)
tracks_eval
# Out:
#                         danceability  energy  key  loudness  mode  \
# 7lPN2DXiMsVn7XUKtOW1CS         0.585   0.436   10    -8.761     1
# 5QO79kh1waicV47BqGRL3g         0.680   0.826    0    -5.487     1
# 0VjIjW4GlUZAMYd2vXMi3b         0.514   0.730    1    -5.934     1
# 4MzXwWMhyBbmu6hOcLVD49         0.731   0.573    4   -10.059     0
# 5Kskr9LcNYa0tpt5f0ZEJx         0.907   0.393    4    -7.636     0
# ...                              ...     ...  ...       ...   ...
# 4lUmnwRybYH7mMzf16xB0y         0.596   0.650    9    -5.167     1
# 1fzf9Aad4y1RWrmwosAK5y         0.588   0.850    4    -6.431     1
# 3E3pb3qH11iny6TFDJvsg5         0.754   0.660    0    -6.811     1
# 3yTkoTuiKRGL2VAlQd7xsC         0.584   0.836    0    -4.925     1
# 4JE6agBLHGA5TaF6FlqfBD         0.331   0.450   10    -5.362     1
#
#                         speechiness  acousticness  instrumentalness  liveness  \
# 7lPN2DXiMsVn7XUKtOW1CS       0.0601       0.72100          0.000013    0.1050
# 5QO79kh1waicV47BqGRL3g       0.0309       0.02120          0.000012    0.5430
# 0VjIjW4GlUZAMYd2vXMi3b       0.0598       0.00146          0.000095    0.0897
# 4MzXwWMhyBbmu6hOcLVD49       0.0544       0.40100          0.000052    0.1130
# 5Kskr9LcNYa0tpt5f0ZEJx       0.0539       0.45100          0.000001    0.1350
# ...                             ...           ...               ...       ...
# 4lUmnwRybYH7mMzf16xB0y       0.3370       0.13800          0.000000    0.1400
# 1fzf9Aad4y1RWrmwosAK5y       0.0318       0.16800          0.002020    0.0465
# 3E3pb3qH11iny6TFDJvsg5       0.2670       0.17900          0.000000    0.1940
# 3yTkoTuiKRGL2VAlQd7xsC       0.0790       0.05580          0.000000    0.0663
# 4JE6agBLHGA5TaF6FlqfBD       0.0340       0.36500          0.004640    0.2200
#
#                         valence    tempo  duration_ms  time_signature
# 7lPN2DXiMsVn7XUKtOW1CS    0.132  143.874       242014               4
# 5QO79kh1waicV47BqGRL3g    0.644  118.051       215627               4
# 0VjIjW4GlUZAMYd2vXMi3b    0.334  171.005       200040               4
# 4MzXwWMhyBbmu6hOcLVD49    0.145  109.928       205090               4
# 5Kskr9LcNYa0tpt5f0ZEJx    0.202  104.949       205458               4
# ...                         ...      ...          ...             ...
# 4lUmnwRybYH7mMzf16xB0y    0.188  133.997       257428               4
# 1fzf9Aad4y1RWrmwosAK5y    0.768   93.003       187310               4
# 3E3pb3qH11iny6TFDJvsg5    0.316   83.000       209299               4
# 3yTkoTuiKRGL2VAlQd7xsC    0.484  104.973       202204               4
# 4JE6agBLHGA5TaF6FlqfBD    0.180  123.829       218755               4
#
# [1162 rows x 13 columns]

# %% [markdown]
# * Next, we acquire the track features.

# %%
track_features_eval = get_track_features(test_ids)
# Out:
# getting from 0 to 50
# getting from 50 to 100
# getting from 100 to 150
# getting from 150 to 200
# getting from 200 to 250
# getting from 250 to 300
# getting from 300 to 350
# getting from 350 to 400
# getting from 400 to 450
# getting from 450 to 500
# getting from 500 to 550
# getting from 550 to 600
# getting from 600 to 650
# getting from 650 to 700
# getting from 700 to 750
# getting from 750 to 800
# getting from 800 to 850
# getting from 850 to 900
# getting from 900 to 950
# getting from 950 to 1000
# getting from 1000 to 1050
# getting from 1050 to 1100
# getting from 1100 to 1150
# getting from 1150 to 1200

# %%
extra_features_eval = pd.DataFrame.from_dict(track_features_eval, orient='index')
extra_features_eval['explicit'] = np.where(extra_features_eval['explicit'] == True, 1, 0)
extra_features_eval['year'] = extra_features_eval['release_date'].apply(lambda x: int(x[0:4]))
extra_features_eval.drop(columns='release_date', inplace=True)
extra_features_eval
# Out:
#                         explicit  year
# 7lPN2DXiMsVn7XUKtOW1CS         1  2021
# 5QO79kh1waicV47BqGRL3g         1  2020
# 0VjIjW4GlUZAMYd2vXMi3b         0  2020
# 4MzXwWMhyBbmu6hOcLVD49         1  2020
# 5Kskr9LcNYa0tpt5f0ZEJx         1  2021
# ...                          ...   ...
# 4lUmnwRybYH7mMzf16xB0y         1  2021
# 1fzf9Aad4y1RWrmwosAK5y         0  2021
# 3E3pb3qH11iny6TFDJvsg5         1  2021
# 3yTkoTuiKRGL2VAlQd7xsC         0  2021
# 4JE6agBLHGA5TaF6FlqfBD         0  2017
#
# [1162 rows x 2 columns]

# %% [markdown]
# * We merge the two DataFrames to obtain the high level audio and track features united.

# %%
tracks_eval = tracks_eval.merge(extra_features_eval, left_index=True, right_index=True, how='inner')
tracks_eval
# Out:
#                         danceability  energy  key  loudness  mode  \
# 7lPN2DXiMsVn7XUKtOW1CS         0.585   0.436   10    -8.761     1
# 5QO79kh1waicV47BqGRL3g         0.680   0.826    0    -5.487     1
# 0VjIjW4GlUZAMYd2vXMi3b         0.514   0.730    1    -5.934     1
# 4MzXwWMhyBbmu6hOcLVD49         0.731   0.573    4   -10.059     0
# 5Kskr9LcNYa0tpt5f0ZEJx         0.907   0.393    4    -7.636     0
# ...                              ...     ...  ...       ...   ...
# 4lUmnwRybYH7mMzf16xB0y         0.596   0.650    9    -5.167     1
# 1fzf9Aad4y1RWrmwosAK5y         0.588   0.850    4    -6.431     1
# 3E3pb3qH11iny6TFDJvsg5         0.754   0.660    0    -6.811     1
# 3yTkoTuiKRGL2VAlQd7xsC         0.584   0.836    0    -4.925     1
# 4JE6agBLHGA5TaF6FlqfBD         0.331   0.450   10    -5.362     1
#
#                         speechiness  acousticness  instrumentalness  liveness  \
# 7lPN2DXiMsVn7XUKtOW1CS       0.0601       0.72100          0.000013    0.1050
# 5QO79kh1waicV47BqGRL3g       0.0309       0.02120          0.000012    0.5430
# 0VjIjW4GlUZAMYd2vXMi3b       0.0598       0.00146          0.000095    0.0897
# 4MzXwWMhyBbmu6hOcLVD49       0.0544       0.40100          0.000052    0.1130
# 5Kskr9LcNYa0tpt5f0ZEJx       0.0539       0.45100          0.000001    0.1350
# ...                             ...           ...               ...       ...
# 4lUmnwRybYH7mMzf16xB0y       0.3370       0.13800          0.000000    0.1400
# 1fzf9Aad4y1RWrmwosAK5y       0.0318       0.16800          0.002020    0.0465
# 3E3pb3qH11iny6TFDJvsg5       0.2670       0.17900          0.000000    0.1940
# 3yTkoTuiKRGL2VAlQd7xsC       0.0790       0.05580          0.000000    0.0663
# 4JE6agBLHGA5TaF6FlqfBD       0.0340       0.36500          0.004640    0.2200
#
#                         valence    tempo  duration_ms  time_signature  \
# 7lPN2DXiMsVn7XUKtOW1CS    0.132  143.874       242014               4
# 5QO79kh1waicV47BqGRL3g    0.644  118.051       215627               4
# 0VjIjW4GlUZAMYd2vXMi3b    0.334  171.005       200040               4
# 4MzXwWMhyBbmu6hOcLVD49    0.145  109.928       205090               4
# 5Kskr9LcNYa0tpt5f0ZEJx    0.202  104.949       205458               4
# ...                         ...      ...          ...             ...
# 4lUmnwRybYH7mMzf16xB0y    0.188  133.997       257428               4
# 1fzf9Aad4y1RWrmwosAK5y    0.768   93.003       187310               4
# 3E3pb3qH11iny6TFDJvsg5    0.316   83.000       209299               4
# 3yTkoTuiKRGL2VAlQd7xsC    0.484  104.973       202204               4
# 4JE6agBLHGA5TaF6FlqfBD    0.180  123.829       218755               4
#
#                         explicit  year
# 7lPN2DXiMsVn7XUKtOW1CS         1  2021
# 5QO79kh1waicV47BqGRL3g         1  2020
# 0VjIjW4GlUZAMYd2vXMi3b         0  2020
# 4MzXwWMhyBbmu6hOcLVD49         1  2020
# 5Kskr9LcNYa0tpt5f0ZEJx         1  2021
# ...                          ...   ...
# 4lUmnwRybYH7mMzf16xB0y         1  2021
# 1fzf9Aad4y1RWrmwosAK5y         0  2021
# 3E3pb3qH11iny6TFDJvsg5         1  2021
# 3yTkoTuiKRGL2VAlQd7xsC         0  2021
# 4JE6agBLHGA5TaF6FlqfBD         0  2017
#
# [1162 rows x 15 columns]

# %% [markdown]
# * Furthermore, we acquire the low level audio features.
# * We edit the function that performs the requests to work for a specific list of tracks (and not until a limit).

# %%
def get_audio_analysis_specific(track_ids):    
    audio_analysis_pitch = {}
    audio_analysis_timbre = {}
    audio_analysis_loudness = {}

    for id in track_ids:
        try:
            track_analysis = sp.audio_analysis(id)
            pitches = get_pitch(track_analysis['segments'])
            timbre = get_timbre(track_analysis['segments'])
            loudness = get_loudness(track_analysis['segments'])

            audio_analysis_pitch.update({ id : pitches})
            audio_analysis_timbre.update({ id : timbre})
            audio_analysis_loudness.update({ id : loudness})

        except Exception:
            print('error:', id)
    
    return audio_analysis_pitch, audio_analysis_timbre, audio_analysis_loudness

# %%
audio_analysis_pitch_eval, audio_analysis_timbre_eval, audio_analysis_loudness_eval = get_audio_analysis_specific(test_ids)
# Out:
# HTTP Error for GET to https://api.spotify.com/v1/audio-analysis/4LaGu95Ui2s4vprSQYWUAZ with Params: {} returned 404 due to analysis not found
# error: 4LaGu95Ui2s4vprSQYWUAZ

# %% [markdown]
# * We see that one of the evaluation tracks has no low level analysis and as a result we will not use it during the final evaluation.

# %%
print(len(audio_analysis_pitch_eval), len(audio_analysis_timbre_eval), len(audio_analysis_loudness_eval))
# Out:
# 1161 1161 1161

# %% [markdown]
# * We perform the same transformations as before (calculate means and merge), in order to obtain the final DataFrame that has all the necesssary data.

# %% [markdown]
# * Mean calculations:

# %%
audio_analysis_pitch_mean_eval = {}
for track_id, analysis in audio_analysis_pitch_eval.items():
    pitch_mean = np.mean(analysis, axis=0)
    audio_analysis_pitch_mean_eval.update({ track_id : pitch_mean})

# %%
audio_analysis_timbre_mean_eval = {}
for track_id, analysis in audio_analysis_timbre_eval.items():
    timbre_mean = np.mean(analysis, axis=0)
    audio_analysis_timbre_mean_eval.update({ track_id : timbre_mean})

# %%
audio_analysis_loudness_mean_eval = {}
for track_id, analysis in audio_analysis_loudness_eval.items():
    loudness_mean = np.mean(analysis, axis=0)
    audio_analysis_loudness_mean_eval.update({ track_id : loudness_mean})

# %% [markdown]
# * Merge procedures:

# %%
pitch_analysis_eval = pd.DataFrame.from_dict(audio_analysis_pitch_mean_eval, orient='index')
pitch_analysis_eval = pitch_analysis_eval.add_prefix('pitch_')
pitch_analysis_eval
# Out:
#                          pitch_0   pitch_1   pitch_2   pitch_3   pitch_4  \
# 7lPN2DXiMsVn7XUKtOW1CS  0.349608  0.367562  0.381938  0.333165  0.233992
# 5QO79kh1waicV47BqGRL3g  0.509999  0.369865  0.293584  0.260545  0.470775
# 0VjIjW4GlUZAMYd2vXMi3b  0.657973  0.627336  0.334794  0.341640  0.292579
# 4MzXwWMhyBbmu6hOcLVD49  0.533442  0.548317  0.340552  0.299635  0.430683
# 5Kskr9LcNYa0tpt5f0ZEJx  0.428253  0.406315  0.398415  0.222132  0.477949
# ...                          ...       ...       ...       ...       ...
# 4lUmnwRybYH7mMzf16xB0y  0.561508  0.683205  0.419908  0.403616  0.429285
# 1fzf9Aad4y1RWrmwosAK5y  0.327824  0.477446  0.236671  0.310013  0.575318
# 3E3pb3qH11iny6TFDJvsg5  0.511021  0.497643  0.347654  0.238971  0.327831
# 3yTkoTuiKRGL2VAlQd7xsC  0.663608  0.480316  0.348203  0.273951  0.353918
# 4JE6agBLHGA5TaF6FlqfBD  0.305310  0.299019  0.430959  0.433306  0.222903
#
#                          pitch_5   pitch_6   pitch_7   pitch_8   pitch_9  \
# 7lPN2DXiMsVn7XUKtOW1CS  0.421520  0.217720  0.279433  0.162397  0.243067
# 5QO79kh1waicV47BqGRL3g  0.272121  0.243054  0.378965  0.232045  0.332873
# 0VjIjW4GlUZAMYd2vXMi3b  0.488248  0.285965  0.315812  0.264716  0.234030
# 4MzXwWMhyBbmu6hOcLVD49  0.286694  0.319173  0.355134  0.270570  0.365329
# 5Kskr9LcNYa0tpt5f0ZEJx  0.250945  0.362671  0.211838  0.106474  0.132667
# ...                          ...       ...       ...       ...       ...
# 4lUmnwRybYH7mMzf16xB0y
...       ...       ...
# 4lUmnwRybYH7mMzf16xB0y  -9.769350  -3.421517   0.537746 -6.164586  6.263427
# 1fzf9Aad4y1RWrmwosAK5y -26.533251  -5.507732  -5.732575 -7.295153 -1.181860
# 3E3pb3qH11iny6TFDJvsg5 -13.813517   4.519290   0.073836 -7.527253  1.242939
# 3yTkoTuiKRGL2VAlQd7xsC -27.087110  -0.022057  -3.249742 -8.522278  5.259177
# 4JE6agBLHGA5TaF6FlqfBD -24.236085   8.301992  -1.563800 -6.765872 -4.512180
#
#                         timbre_10  timbre_11
# 7lPN2DXiMsVn7XUKtOW1CS  -9.382599   3.806793
# 5QO79kh1waicV47BqGRL3g  -9.379946  -2.194406
# 0VjIjW4GlUZAMYd2vXMi3b -12.995984  -0.989638
# 4MzXwWMhyBbmu6hOcLVD49 -13.412574  -7.004807
# 5Kskr9LcNYa0tpt5f0ZEJx -21.408289   4.122929
# ...                           ...        ...
# 4lUmnwRybYH7mMzf16xB0y -21.499195  -6.566107
# 1fzf9Aad4y1RWrmwosAK5y  -5.934610   0.560949
# 3E3pb3qH11iny6TFDJvsg5 -20.744944  -4.064045
# 3yTkoTuiKRGL2VAlQd7xsC -13.858022  -6.516408
# 4JE6agBLHGA5TaF6FlqfBD  -9.327318   1.839062
#
# [1161 rows x 12 columns]

# %%
loudness_analysis_eval = pd.DataFrame.from_dict(audio_analysis_loudness_mean_eval, orient='index')
loudness_analysis_eval.columns = ['loudness_start', 'loudness_max_time', 'loudness_max']
loudness_analysis_eval
# Out:
#                         loudness_start  loudness_max_time  loudness_max
# 7lPN2DXiMsVn7XUKtOW1CS      -20.136485           0.071430    -11.846137
# 5QO79kh1waicV47BqGRL3g      -12.366643           0.059288     -5.266731
# 0VjIjW4GlUZAMYd2vXMi3b      -13.010345           0.059692     -6.141568
# 4MzXwWMhyBbmu6hOcLVD49      -21.296216           0.059611    -12.379307
# 5Kskr9LcNYa0tpt5f0ZEJx      -23.091459           0.055798    -10.516077
# ...                                ...                ...           ...
# 4lUmnwRybYH7mMzf16xB0y      -16.965315           0.058101     -6.245689
# 1fzf9Aad4y1RWrmwosAK5y      -14.089263           0.049178     -7.443791
# 3E3pb3qH11iny6TFDJvsg5      -19.211222           0.061354     -8.765307
# 3yTkoTuiKRGL2VAlQd7xsC      -12.448574           0.062063     -5.485316
# 4JE6agBLHGA5TaF6FlqfBD      -13.732306           0.093630     -7.868360
#
# [1161 rows x 3 columns]

# %%
audio_analysis_eval = pitch_analysis_eval.merge(timbre_analysis_eval.merge(loudness_analysis_eval, left_index=True, right_index=True, how='inner'), left_index=True, right_index=True, how='inner')
audio_analysis_eval
# Out:
#                          pitch_0   pitch_1   pitch_2   pitch_3   pitch_4  \
# 7lPN2DXiMsVn7XUKtOW1CS  0.349608  0.367562  0.381938  0.333165  0.233992
# 5QO79kh1waicV47BqGRL3g  0.509999  0.369865  0.293584  0.260545  0.470775
# 0VjIjW4GlUZAMYd2vXMi3b  0.657973  0.627336  0.334794  0.341640  0.292579
# 4MzXwWMhyBbmu6hOcLVD49  0.533442  0.548317  0.340552  0.299635  0.430683
# 5Kskr9LcNYa0tpt5f0ZEJx  0.428253  0.406315  0.398415  0.222132  0.477949
# ...                          ...       ...       ...       ...       ...
# 4lUmnwRybYH7mMzf16xB0y
#
#                         speechiness  acousticness  instrumentalness  liveness  \
# 7lPN2DXiMsVn7XUKtOW1CS       0.0601       0.72100          0.000013    0.1050
# 5QO79kh1waicV47BqGRL3g       0.0309       0.02120          0.000012    0.5430
# 0VjIjW4GlUZAMYd2vXMi3b       0.0598       0.00146          0.000095    0.0897
# 4MzXwWMhyBbmu6hOcLVD49       0.0544       0.40100          0.000052    0.1130
# 5Kskr9LcNYa0tpt5f0ZEJx       0.0539       0.45100          0.000001    0.1350
# ...                             ...           ...               ...       ...
# 4lUmnwRybYH7mMzf16xB0y       0.3370       0.13800          0.000000    0.1400
# 1fzf9Aad4y1RWrmwosAK5y       0.0318       0.16800          0.002020    0.0465
# 3E3pb3qH11iny6TFDJvsg5       0.2670       0.17900          0.000000    0.1940
# 3yTkoTuiKRGL2VAlQd7xsC       0.0790       0.05580          0.000000    0.0663
# 4JE6agBLHGA5TaF6FlqfBD       0.0340       0.36500          0.004640    0.2200
#
#                         valence    tempo  duration_ms  time_signature  \
# 7lPN2DXiMsVn7XUKtOW1CS    0.132  143.874       242014               4
# 5QO79kh1waicV47BqGRL3g    0.644  118.051       215627               4
# 0VjIjW4GlUZAMYd2vXMi3b    0.334  171.005       200040               4
# 4MzXwWMhyBbmu6hOcLVD49    0.145  109.928       205090               4
# 5Kskr9LcNYa0tpt5f0ZEJx    0.202  104.949       205458               4
# ...                         ...      ...          ...             ...
# 4lUmnwRybYH7mMzf16xB0y    0.188  133.997       257428               4
# 1fzf9Aad4y1RWrmwosAK5y    0.768   93.003       187310               4
# 3E3pb3qH11iny6TFDJvsg5    0.316   83.000       209299               4
# 3yTkoTuiKRGL2VAlQd7xsC    0.484  104.973       202204               4
# 4JE6agBLHGA5TaF6FlqfBD    0.180  123.829       218755               4
#
#                         explicit  year
# 7lPN2DXiMsVn7XUKtOW1CS         1  2021
# 5QO79kh1waicV47BqGRL3g         1  2020
# 0VjIjW4GlUZAMYd2vXMi3b         0  2020
# 4MzXwWMhyBbmu6hOcLVD49         1  2020
# 5Kskr9LcNYa0tpt5f0ZEJx         1  2021
# ...                          ...   ...
# 4lUmnwRybYH7mMzf16xB0y         1  2021
# 1fzf9Aad4y1RWrmwosAK5y         0  2021
# 3E3pb3qH11iny6TFDJvsg5         1  2021
# 3yTkoTuiKRGL2VAlQd7xsC         0  2021
# 4JE6agBLHGA5TaF6FlqfBD         0  2017
#
# [1161 rows x 42 columns]

# %% [markdown]
# * We export the evaluation data to a csv file.

# %%
low_level_tracks_eval.to_csv('data/low_level_tracks_eval.csv')

# %% [markdown]
# * Last, we save the detailed data of the segments for future use (CNN).
# * We save the results in .npy files.

# %%
np.save('pitch_eval.npy',audio_analysis_pitch_eval)
np.save('timbre_eval.npy',audio_analysis_timbre_eval)
